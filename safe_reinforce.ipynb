# %% [markdown]
# <a href="https://colab.research.google.com/github/da2985/e6885-adnet/blob/main/safe_reinforce.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Imports & Starting Configs
#
# Please use the following two lines to load from Google Drive
#
# If your file is not there, upload it to https://drive.google.com/drive/folders/1tsPKyB2E1nW8Qw--kZ9GaeGW2u2-XoV6?usp=sharing

# %%
# This must be run within a Google Colab environment 
from google.colab import drive  
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
import sys
import os

sys.path.append('/content/gdrive/EE6885')

os.chdir("/content/gdrive/My Drive/EE6885")

# %%
# !ls adnet_datasets/OTB
# Out:
#  Basketball   Car24	 Dog1	      Human5	     MountainBike   Surfer
#  Bird2	      Car4	 Doll	      Human6	     Panda	    Suv
#  BlurBody     CarDark	 DragonBaby   Human7	     RedTeam	    Sylvester
#  BlurCar1     CarScale	 Dudek	      Human8	     Rubik	    Tiger1
#  BlurCar2     ClifBar	 FaceOcc1     Human9	     Shaking	    Tiger2
#  BlurCar3     Coke	 FaceOcc2     Ironman	     Singer1	    Toy
#  BlurCar4     Couple	 Fish	      Jogging	     Singer2	    Trans
#  BlurFace     Coupon	 FleetFace    Jump	     Skater	    Trellis
#  BlurOwl      Crossing	 Football1    Jumping	     Skater2	    Twinnings
#  Board	      Crowds	 Freeman1     KiteSurf	    'Skater2 (1)'   Vase
#  Bolt	      Dancer	 Girl	      Lemming	     Skating1	    Walking
#  Bolt2	      Dancer2	 Girl2	      Liquor	     Skating2	    Walking2
#  Box	      David2	 Gym	      Man	     Skating3	    Woman
#  Boy	      David3	 Human2       Matrix	     Skiing
#  Car1	      Deer	 Human3       Mhyang	     Soccer
#  Car2	      Dog	 Human4       MotorRolling   Subway

# %%
pip install hdf5storage tensorflow-addons
# Out:
# Requirement already satisfied: hdf5storage in /usr/local/lib/python3.7/dist-packages (0.1.18)
# Requirement already satisfied: tensorflow-addons in /usr/local/lib/python3.7/dist-packages (0.15.0)
# Requirement already satisfied: h5py>=2.1 in /usr/local/lib/python3.7/dist-packages (from hdf5storage) (3.1.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from hdf5storage) (1.19.5)
# Requirement already satisfied: cached-property in /usr/local/lib/python3.7/dist-packages (from h5py>=2.1->hdf5storage) (1.5.2)
# Requirement already satisfied: typeguard>=2.7 in /usr/local/lib/python3.7/dist-packages (from tensorflow-addons) (2.7.1)

# %%
import numpy as np
import tensorflow as tf
import tensorflow_addons as tfa

import tensorflow_probability as tfp
from tensorflow.keras.optimizers import Adam, SGD
from tensorflow.keras import regularizers
import tensorflow.experimental.numpy as tnp

import cv2
import glob
import hdf5storage
import math
import random
import re

import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import matplotlib.patches as patches
import scipy.io as sio

import linecache

from typing import Dict, List, Tuple
from operator import add
import copy

from numpy.random import seed
from datetime import datetime

# %%
 # %load_ext autoreload 
 # %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # Configurations

# %%
#@markdown Network configurations
LEARNING_RATE = 1e-4 #@param {type:"number"}
GOAL_IOU = 0.7 #@param {type:"number"}

# The length of the action buffer
L = 10 #@param {type:"number"}
# Max Trajectory Length 
MAX_TRAJECTORY_LENGTH =  10#@param {type:"number"}
POLICY_TYPE = "stochastic" #@param ["deterministic", "stochastic"] {type:"string"}
DROPOUT_4 = 0.5 #@param {type:"number"}
DROPOUT_5 = 0.5 #@param {type:"number"}
N_EPOCHS =  3#@param {type:"number"}

# Number of retries to collect sequence loss sum (to reduce variance)
N_RETRIES =   1#@param {type:"number"}

# Randomizes the order in which frames are trained on from a video clip
RANDOMIZE_TRAINING = False #@param {type:"boolean"}

# The paper uses sum. I thought avg would help address giant swings, but the training was taking way too long
# with negligible updates
GRAD_ACCUM_SCHEME = "sum" #@param ["avg", "sum"] {type:"string"}

# Use to avoid overly long trajectories. 
# During trajectory collection, we were not receiving 
# enough positvie signals
PREMATURE_BREAK = False #@param {type:"boolean"}


#@markdown ---
#@markdown Loss/Reward Constants
# This is a probability offset for adding noise since log(P(a|s)=1)=0
PROB_OFFSET = 1e-5 #@param {type:"number"} 
# This is the discount factor
GAMMA = 1 #@param {type:"number"}

# The paper uses final_bbox where only the final bounding box placement is accounted
# in reward calculation. individ_bbox individually assign rewards per each bounding box.
REWARD_SCHEME = "only_final_bbox" #@param ["only_final_bbox", "final_bbox", "individ_bbox"] {type:"string"}

#@markdown ---
#@markdown Bounding Box/Patch Constants (probably avoid touching)
ALPHA = 0.03 #@param {type:"number"}
MIN_WINDOW_SIZE = 10 #@param {type:"number"}
PATCH_X = 112 #@param {type:"number"}
PATCH_Y = 112 #@param {type:"number"}
N_CHANNELS = 3 #@param {type:"number"}

#@markdown ---
RANDOM_SEED = 6885

# %%
seed(RANDOM_SEED)
tf.random.set_seed(RANDOM_SEED)

DATASET_PATH = "adnet_datasets/OTB/*" #@param {type:"string"}
ALL_DATASETS_LIST = glob.glob(DATASET_PATH)

# %% [markdown]
# ### Successful Configurations (Minimize Me Please)

# %%
### SUCCESSFUL CONFIGS

# 12/18 4:41 PM
# #@markdown Network configurations
# LEARNING_RATE = 1e-4 #@param {type:"number"}
# # The length of the action buffer
# L = 10 #@param {type:"number"}
# # Max Trajectory Length 
# MAX_TRAJECTORY_LENGTH = 20 #@param {type:"number"}
# POLICY_TYPE = "stochastic" #@param ["deterministic", "stochastic"] {type:"string"}
# DROPOUT_4 = 0.5 #@param {type:"number"}
# DROPOUT_5 = 0.5 #@param {type:"number"}
# N_EPOCHS =  1#@param {type:"number"}

# # Number of retries to collect sequence loss sum (to reduce variance)
# N_RETRIES =  4 #@param {type:"number"}

# # Randomizes the order in which frames are trained on from a video clip
# RANDOMIZE_TRAINING = True #@param {type:"boolean"}
# GRAD_ACCUM_SCHEME = "sum" #@param ["avg", "sum"] {type:"string"}
# # The paper uses sum


# #@markdown ---
# #@markdown Loss/Reward Constants
# # This is a probability offset for adding noise since log(P(a|s)=1)=0
# PROB_OFFSET = 1e-5 #@param {type:"number"} 
# # This is the discount factor
# GAMMA = 0.99 #@param {type:"number"}
# REWARD_SCHEME = "final_bbox" #@param ["final_bbox", "individ_bbox"] {type:"string"}

# #@markdown ---
# #@markdown Bounding Box/Patch Constants (probably avoid touching)
# ALPHA = 0.03 #@param {type:"number"}
# MIN_WINDOW_SIZE = 10 #@param {type:"number"}
# PATCH_X = 112 #@param {type:"number"}
# PATCH_Y = 112 #@param {type:"number"}
# N_CHANNELS = 3 #@param {type:"number"}

# #@markdown ---
# RANDOM_SEED = 6885

# %% [markdown]
# ## Model Definitions

# %%
class ADNET(tf.keras.Model):

    ACTION_DIM = 11
    K = 10
    CONF_SCORE_DIM = 2

    def __init__(self):
        super(ADNET, self).__init__()

        self.action_history = tf.keras.layers.Input(shape = (1,1, ADNET.ACTION_DIM * ADNET.K))

        self.conv1 = tf.keras.layers.Conv2D(filters = 96, kernel_size = (7, 7), strides = (2, 2), padding = 'VALID', activation = 'relu', name = 'conv_1')
        self.max1  = tf.keras.layers.MaxPooling2D(pool_size=(3,3), strides = (1, 1), padding = 'VALID')
        self.conv2 = tf.keras.layers.Conv2D(filters = 256, kernel_size = (5, 5), strides = (2, 2), padding = 'VALID', activation = 'relu', name = 'conv_2')
        self.max2  = tf.keras.layers.MaxPool2D(pool_size=(3, 3), strides = (2, 2), padding = 'VALID')
        self.conv3 = tf.keras.layers.Conv2D(filters = 512, kernel_size = (3, 3), strides = (2, 2), padding = 'VALID', activation = 'relu', name = 'conv_3')
        self.max3  = tf.keras.layers.MaxPool2D(pool_size=(3, 3), strides = (1, 1), padding = 'VALID')
        
        self.fc1 = tf.keras.layers.Conv2D(filters = 512, kernel_size = (3, 3), padding = 'VALID', activation = 'relu', name = 'fc1')
        self.fc2 = tf.keras.layers.Conv2D(filters = 512, kernel_size = (1,1), padding = 'VALID', activation = 'relu', name = 'fc2')
        self.fc3 = tf.keras.layers.Conv2D(filters = 11, kernel_size = (1,1), padding = 'VALID', name = 'fc3',activation="softmax")
        self.fc4 = tf.keras.layers.Conv2D(filters = 2, kernel_size = (1,1), padding = 'VALID', name = 'fc4',activation="softmax")

        # TODO: ADD A SEED
        self.dropout1=tf.keras.layers.Dropout(DROPOUT_4)
        self.dropout2=tf.keras.layers.Dropout(DROPOUT_5)
        

    def build(self):
      super(ADNET, self).build((None, 112, 112, 3))
      self.action_history = np.zeros(shape = (1,1,1,110))


    def call(self, input_tensor, training=False):
        x = self.conv1(input_tensor)
        x = self.max1(x)
        x = self.conv2(x)
        x = self.max2(x)
        x = self.conv3(x)
        x = self.max3(x)

        x = self.fc1(x)
        x = self.dropout1(x)
        x = self.fc2(x)
        x = self.dropout2(x)
        x = tf.keras.layers.Concatenate(axis=-1)([x, self.action_history])
        action = self.fc3(x)
        confidence = self.fc4(x)
        return [action, confidence]


    def compile(self, optimizer):
   		super().compile(optimizer, loss={
         'output_1':tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False),
         'output_2': tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False)
         })
     
    def getEmbedding(self,input_tensor):
        x = self.conv1(input_tensor)
        x = self.max1(x)
        x = self.conv2(x)
        x = self.max2(x)
        x = self.conv3(x)
        x = self.max3(x)
        return tf.reshape(x,(-1,))

    def getFC1(self,input_tensor):
        x = self.conv1(input_tensor)
        x = self.max1(x)
        x = self.conv2(x)
        x = self.max2(x)
        x = self.conv3(x)
        x = self.max3(x)
        x = self.fc1(x)
        return x

    def setActionHistory(self, action_history):
      self.action_history = action_history.reshape(
          (1, 1, 1, ADNET.ACTION_DIM * ADNET.K))

    def updateActionHistory(self, a: int=8) -> tnp.ndarray:
      '''
      Left-to-right FIFO queue of actions
      '''
      ah = np.array(self.action_history).flatten()
      ah[ADNET.ACTION_DIM:] = ah[:-ADNET.ACTION_DIM]
      ah[:ADNET.ACTION_DIM] = 0 
      ah[a] = 1
      self.setActionHistory(ah)
      return ah

    def clearActionHistory(self):
      self.action_history = tf.zeros((1, 1, 1, ADNET.ACTION_DIM * ADNET.K))

    def getPrettyActionHistory(self):
      action_hist = tf.reshape(model.action_history, [-1])
      sbuffer = "["
      for i, x in enumerate(action_hist):
        if i > 0 and i % model.ACTION_DIM == 0:
          sbuffer+= "\x1b[35m,\x1b[0m"
        if x == 1:
          sbuffer += "\x1b[35m{0}\x1b[0m".format(int(x))
        else:
          sbuffer += "{0}".format(int(x))
      sbuffer += "]"
      return sbuffer 


    def debugModelSummary(self):
      '''
      call model.debugModelSummary().summary() to get around the inconvenience 
      from model.summary() returning 'multiple' for each layer's output shape
      '''
      dummyInput = tf.keras.layers.Input(shape = (112,112,3))
      return tf.keras.Model(inputs=[dummyInput], outputs = self.call(dummyInput))

def setAllWeights(model, weights):
  model.layers[0].set_weights([weights["conv1f"], tf.reshape(weights["conv1b"],(96,))])
  model.layers[2].set_weights([weights["conv2f"], tf.reshape(weights["conv2b"],(256,))])
  model.layers[4].set_weights([weights["conv3f"], tf.reshape(weights["conv3b"],(512,))])
  model.layers[6].set_weights([weights["fc4f"], tf.reshape(weights["fc4b"],(512,))])
  model.layers[7].set_weights([weights["fc5f"], tf.reshape(weights["fc5b"],(512,))])
  model.layers[8].set_weights([weights["fc6_1f"], tf.zeros(11)])
  model.layers[9].set_weights([weights["fc6_2f"], tf.zeros(2)])


def setWeights(model, weights, weights2):
  model.layers[0].set_weights([weights2["conv1f"],tf.reshape(weights2["conv1b"],(96,))])
  model.layers[2].set_weights([weights2["conv2f"],tf.reshape(weights2["conv2b"],(256,))])
  model.layers[4].set_weights([weights2["conv3f"],tf.reshape(weights2["conv3b"],(512,))])
  
  model.layers[6].set_weights([weights["fc4f"],tf.reshape(weights["fc4b"],(512,))])
  model.layers[7].set_weights([weights["fc5f"],tf.reshape(weights["fc5b"],(512,))])
  model.layers[8].set_weights([weights["fc6_1f"],tf.zeros(11)])
  model.layers[9].set_weights([weights["fc6_2f"],tf.zeros(2)])
  
  return model

print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
# Out:
# Num GPUs Available:  1

# %%
class ADNET_v2(tf.keras.Model):
    def __init__(self):
        super(ADNET_v2, self).__init__()

        #self.action_history = tf.keras.layers.Input(shape = (1,1,110))
        self.action_history = tf.keras.layers.Input(shape = (110))

        self.resnet=tf.keras.applications.ResNet50V2(include_top=False,weights="imagenet",input_shape=(112,112,3),pooling="max")
        #self.resnet = tf.keras.applications.ResNet50V2(include_top=False,weights="imagenet",input_shape=(112,112,3),pooling=None)
        #self.conv1 = tf.keras.layers.Conv2D(filters = 128, kernel_size = (4,4), padding = 'VALID', name = 'fc4',activation="relu")
        
        self.fc1 = tf.keras.layers.Dense(512,kernel_initializer='glorot_uniform',activation = 'relu', name = 'fc1')
        self.fc2 = tf.keras.layers.Dense(512,kernel_initializer='glorot_uniform', activation = 'relu', name = 'fc2')
        self.fc3 = tf.keras.layers.Dense(11,kernel_initializer='glorot_uniform', name = 'fc3',activation="softmax")
        self.fc4 = tf.keras.layers.Dense(2,kernel_initializer='glorot_uniform',name = 'fc4',activation="softmax")

        self.dropout1=tf.keras.layers.Dropout(0)
        self.dropout2=tf.keras.layers.Dropout(0)
        

    def build(self, action_history):
      super(ADNET_v2, self).build((None, 112, 112, 3))
      self.action_history=action_history
      self.resnet.trainable = False


    def setActionHistory(self, action_history):
      self.action_history=action_history


    def call(self, input_tensor, training=False):
        x = self.resnet(input_tensor)
        #x = self.conv1(x)

        x = self.fc1(x)
        x=  self.dropout1(x)
        x = self.fc2(x)
        x=  self.dropout2(x)
        x = tf.keras.layers.Concatenate(axis=-1)([x, self.action_history])
        action = self.fc3(x)
        confidence = self.fc4(x)
        return [action, confidence]

     
    def debugModelSummary(self):
      '''
      call model.debugModelSummary().summary() to get around the inconvenience 
      from model.summary() returning 'multiple' for each layer's output shape
      '''
      dummyInput = tf.keras.layers.Input(shape = (112,112,3))
      return tf.keras.Model(inputs=[dummyInput], outputs = self.call(dummyInput))

# %% [markdown]
# # Helper Functions

# %% [markdown]
# ### Plotting & Debugging

# %%
def get_ground_truths(ground_truth_file: str) -> np.array:
  '''
  Use me to convert a ground_truth_file to a numpy array
  '''
  with open(ground_truth_file) as f:
    ground_truths = f.readlines()
    to_nparray = lambda s: np.array(re.findall('\d+', s), dtype=int)
    truths = list(map(to_nparray, ground_truths))
    return np.asarray(truths)
  return None

def plotNpImageBBox(img: np.array, bbox: np.array) -> np.array:
  '''
  Plots the bounding box on an image and returns the bounding box
  '''
  fig, ax = plt.subplots()
  x, y, w, h = bbox
  rect = patches.Rectangle((x, y), w, h, linewidth=1, edgecolor='r', facecolor='none')
  ax.add_patch(rect)
  plt.imshow(img)
  return bbox

def plotNpImageBBoxes(img: np.array, src_bbox: np.array, target_bbox: np.array, 
                      pred_bbox: np.array) -> np.array:
  '''
  Plots the bounding boxes on an image and returns the bounding box
  '''
  fig, ax = plt.subplots()
  x1, y1, w1, h1 = src_bbox
  x2, y2, w2, h2 = target_bbox
  x3, y3, w3, h3 = pred_bbox
  rect1 = patches.Rectangle((x1, y1), w1, h1, linewidth=1, edgecolor='b', facecolor='none')
  rect2 = patches.Rectangle((x2, y2), w2, h2, linewidth=1, edgecolor='g', facecolor='none')
  rect3 = patches.Rectangle((x3, y3), w3, h3, linewidth=1, edgecolor='r', facecolor='none')
  ax.add_patch(rect1)
  ax.add_patch(rect2)
  ax.add_patch(rect3)
  plt.imshow(img)
  return pred_bbox  

def plotImageBBox(img: str, bbox: np.array) -> np.array:
  '''
  Plots the bounding box on an image (from given filepath) and returns the 
  bounding box
  '''
  img = cv2.imread(img)
  img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
  plotNpImageBBox(img, bbox)
  return bbox

def plotDatasetImageBBox(dataset: str, frame_no: int) -> Tuple[np.array, int]:
  '''
  Plot an image's bounding box. Returns the ground truth and frame number.
  WORKS FOR OTB100
  '''
  imgs = sorted(glob.glob("{0}/img/*".format(dataset)))
  gt = get_ground_truths("{0}/groundtruth_rect.txt".format(dataset))
  plotImageBBox(imgs[frame_no], gt[frame_no])
  return gt[frame_no], frame_no


# print(plotDatasetImageBBox("adnet_datasets/OTB/Basketball", 50)[0])
print(plotDatasetImageBBox("adnet_datasets/OTB/BlurBody", 10)[0])
# Out:
# [171 128  99 316]

# %% [markdown]
# ### Movement

# %%
STOP_ACTION_INDEX = 8

def getFrame(f_path: str) -> np.array:
  print("Frame path: {0}".format(f_path))
  img = cv2.imread(f_path)
  return cv2.cvtColor(img, cv2.COLOR_BGR2RGB)


def calculate_IOU(bbox1: np.array, bbox2: np.array):
    x1, y1, w1, h1 = bbox1
    x2, y2, w2, h2 = bbox2
           
    i_x1 = max(x1, x2)
    i_y1 = max(y1, y2)
    i_x2 = min(x1 + w1, x2 + w2)
    i_y2 = min(y1 + h1, y2 + h2)
    if i_x1 >= i_x2 or i_y1 >= i_y2:
      return 0.0

    intersection_area = (i_x2 - i_x1) * (i_y2 - i_y1)
    box1_area = w1 * h1
    box2_area = w2 * h2
    
    iou = intersection_area / float(box1_area + box2_area - intersection_area)
    return iou


def move(image: np.array, bbox: np.array, action: str, 
         stride_magnitude: int=1) -> np.array:
  '''
  Returns the new bounding box after taking an action: 
  {"left", "right", "up", "down"}. Use stride to indicate the step size.
  '''
  if action not in set(["left", "right", "up", "down"]):
    raise RuntimeError("Invalid action taken :(") 
  
  x, y, w, h = bbox
  if action in set(["left", "right"]):
    step = max(1, int(ALPHA * w)) * stride_magnitude * (-1 if action=="left" else 1)
    x = min(max(0, int(x + step)), int(image.shape[1] - w - 1)) 
  else:
    step = max(1, int(ALPHA * h)) * stride_magnitude * (-1 if action=="up" else 1)
    y = min(max(0, int(y + step)), int(image.shape[0] - h - 1)) 

  return np.array([x, y, w, h])


def scale(image: np.array, bbox: np.array, scaleUp: bool):
  x, y, w, h = bbox
  deltaW, deltaH = max(2, ALPHA * w), max(2, ALPHA * h)
  if not scaleUp: 
    deltaW *= -1
    deltaH *= -1
  nw = min(image.shape[1], max(MIN_WINDOW_SIZE, int(w + deltaW))) 
  nh = min(image.shape[0], max(MIN_WINDOW_SIZE, int(h + deltaH)))
  

  x = max(0, min(int(x - deltaW / 2), int(image.shape[1] - w - 1)))
  y = max(0, min(int(y - deltaH / 2), int(image.shape[0] - h - 1)))
  return np.array([x, y, nw, nh])


def selectAction(img: np.array, bbox: np.array, index: int): 
  if index == 0 :
    bbox = move(img, bbox, "left")
  elif index == 1 :
    bbox = move(img, bbox, "left", stride_magnitude=2)
  elif index == 2 :
    bbox = move(img, bbox, "right")
  elif index == 3 :
    bbox = move(img, bbox, "right", stride_magnitude=2)  
  elif index == 4 :
    bbox = move(img, bbox, "up")  
  elif index == 5 :
    bbox = move(img, bbox, "up", stride_magnitude=2)
  elif index == 6 :
    bbox = move(img, bbox, "down")
  elif index == 7 :
    bbox = move(img, bbox, "down", stride_magnitude=2)
  elif index == 8:
    bbox = bbox
  elif index == 9 :
    bbox = scale(img, bbox, False)     
  elif index == 10 :
    bbox = scale(img, bbox, True)    
  else:
    raise ValueError("Invalid action provided: {0}".format(index))

  x, y, w, h = bbox
  # some of the data is just invalid :/
  # assert 0 <= x <= img.shape[1] - w, "x:{0}, w:{1} is out of bounds: [0, {2}]".format(x, w, img.shape[1])
  # assert 0 <= y <= img.shape[0] - h, "y:{0}, h:{1} is out of bounds: [0, {2}]".format(y, h, img.shape[0])
  # assert MIN_WINDOW_SIZE <= w <= img.shape[1], "w:{0}, is invalid".format(w)
  # assert MIN_WINDOW_SIZE <= h <= img.shape[0], "h:{0} is invalid".format(h)
  return index, bbox


def human_readable_action(index: int) -> str:
  '''
  Map action numbers to human readable strings
  '''
  def _get_action(index:int) -> str:
    if index == 0:
      return "left"
    elif index == 1:
      return "2x left"
    elif index == 2:
      return "right"
    elif index == 3:
      return "2x right"
    elif index == 4:
      return "up"
    elif index == 5:
      return "2x up"
    elif index == 6:
      return "down"
    elif index == 7:
      return "2x down"
    elif index == 8:
      return "stop"
    elif index == 9:
      return "scale down"
    elif index == 10 :
      return "scale up"
  return _get_action(index).upper()


def getAction(img: np.array, bbox: np.array, action_probs: np.array):  
  a = -1
  if POLICY_TYPE == "deterministic":
    a = tf.math.argmax(action_probs)
  else:
    action_probs = np.array(action_probs) + PROB_OFFSET
    action_probs /= action_probs.sum()
  
    a = np.random.choice(np.arange(len(action_probs)), p=action_probs)
  return selectAction(img, bbox, a)


def isStop(action: int):
  return action == STOP_ACTION_INDEX

# %% [markdown]
# # REINFORCE Loop

# %% [markdown]
# ### Trajectory Loss Function
#
# TODO: investigate adding https://www.analyticsvidhya.com/blog/2020/11/baseline-for-policy-gradients/
# Or rather https://arxiv.org/pdf/1301.2315.pdf

# %%
def getNonStopScore(bbox1: np.array, bbox2: np.array, gt: np.array) -> float:
  # Issues with this blowing up the gradient in the wrong direction

  def _dist(x1, y1, x2, y2):
    return math.sqrt((x1 - x2) ** 2 + (y1 - y2) ** 2)
  
  prevIou = calculate_IOU(bbox1, gt) 
  nextIou = calculate_IOU(bbox2, gt)
  x1, y1 = bbox1[:2]
  x2, y2 = bbox2[:2]
  xg, yg = gt[:2]

  # if prevIou == nextIou: EXPERIMENTED WITH USING EUCLIDEAN DISTANCE
  #   return -1 * (_dist(x2, y2, xg, yg) - _dist(x1, y1, xg, yg))
  result = nextIou - prevIou 
  return result 

def seqLosses(action_probs: List[np.array], actions_taken: List[int], 
              bboxes: List[np.array], 
              target_bbox: np.array) -> np.array:

    assertMsg = "Invalid trajectory: actions taken ({0}) + 1 != Bboxes length ({1})".format(
              len(actions_taken), len(bboxes)) 
    assert len(actions_taken) + 1 == len(bboxes), assertMsg
          
    src_bbox = np.array(bboxes[0])
    end_bbox = np.array(bboxes[-1])
    print("\x1b[34m>> Calculating frame loss : {0} -> {1} (Target was {2})\x1b[0m".format(
            np.array2string(src_bbox, separator=', '),
            np.array2string(end_bbox, separator=', '),
            np.array2string(target_bbox, separator=', ')))
    rewards = np.zeros(len(actions_taken))
    discounts = np.zeros(len(actions_taken))
    for i, a in enumerate(actions_taken):
      prev_bbox = np.array(bboxes[i])
      next_bbox = np.array(bboxes[i+1])
      ###################### CHANGE REWARD CALCULATION HERE ####################
      if REWARD_SCHEME == "final_bbox":
        rewards[i] = 1 if calculate_IOU(end_bbox, target_bbox) > GOAL_IOU\
                      else -1      
      elif REWARD_SCHEME == "only_final_bbox" and i == len(actions_taken) - 1:
        rewards[i] = 1 if calculate_IOU(end_bbox, target_bbox) > GOAL_IOU\
                      else -1      
      else:
        if isStop(a):
          rewards[i] = 1 if calculate_IOU(next_bbox, target_bbox) > GOAL_IOU else -1
        else:
          rewards[i] = getNonStopScore(prev_bbox, next_bbox, target_bbox) 
      ###################### CHANGE REWARD CALCULATION UP ABOVE ################
      prob_a = action_probs[i][a]
      discounts[i] = GAMMA ** i
      print("   |->> t={0} {1}-Reward ({2}) for {3}:bbox transition: {4} -> {5} w/ P(a|s)={6} and iou={7} and reward={8} and discount={9}"
            .format(i+1, "Stop" if isStop(a) else "Diff", 
                    np.around(rewards[i], decimals=3), 
                    human_readable_action(a).upper(),
                    np.array2string(prev_bbox, separator=', '),
                    np.array2string(next_bbox, separator=', '), prob_a, 
                    calculate_IOU(next_bbox, target_bbox), 
                    rewards[i], discounts[i]), 
            )
    
    gather_idx = [[i, a] for i, a in enumerate(actions_taken)]
    p_a = tf.gather_nd(tf.stack(action_probs), gather_idx)
    p_a = tf.clip_by_value(p_a, PROB_OFFSET, 1 - PROB_OFFSET) # done to prevent 0 reward   
    
    entropy = -1 * tf.math.reduce_sum((tf.math.log(action_probs) * action_probs), 
                                 axis=1) 
    
    discount = tf.convert_to_tensor(discounts, dtype=tf.float32)
    losses = -1 * (discount * rewards * tf.math.log(p_a))
    
    
    print("   |->> Assigned losses: {0}".format(losses))
    return losses

# %% [markdown]
# ### Tracking Procedure
#
# * This function collects trajectories either via argmax deterministic policy or sampling from a stochastic policy

# %%
def getPatch(img: np.array, bbox: np.array) -> tf.Tensor:
  def _patch(img: np.array, bbox: np.array) -> np.array:
    x, y, w, h, = bbox
    return img[y : (y + h), x : (x + w)]
      
  patch = tf.image.resize(_patch(img, bbox), [PATCH_X, PATCH_Y])
  return tf.reshape(patch, (1, PATCH_X, PATCH_Y, N_CHANNELS))


def tracking(model: ADNET, img: np.array, bbox: np.array,
             t: int, target_bbox: np.array, 
             tracking_length: int= MAX_TRAJECTORY_LENGTH):
    """ 
    Runs tracking until # actions > MAX_ACTIONS_SEQ_LIMIT, STOP is taken, or
    oscillation occurs.
    """
    print("|->> Beginning tracking for bbox:{0}".format(bbox))    
    patch = getPatch(img, bbox)
    actions_taken = []
    action_probs = []
    bboxes = [tuple(bbox)]
    prev_score = None
    while len(actions_taken) < tracking_length:
      prev_bbox = bbox.copy()
      
      probs, conf_score = model(patch)
      probs = tf.reshape(probs, (model.ACTION_DIM)) 
      
      a, bbox = getAction(np.array(img), bbox, probs)
      prev_iou = calculate_IOU(prev_bbox, target_bbox)      
      iou = calculate_IOU(bbox, target_bbox)   

      if tuple(bbox) in bboxes:
        print("|->> Revisiting bbox: {0}. ACtion {1} did nothing. Breaking action sequence"
                  .format(bbox, a))
        print("   |->> Trajectory ending is FORCED".format(iou))
        a, bbox = 8, prev_bbox
        if len(actions_taken) > 0:
          # We observed too many trajectory STOPS were leading to gradient updates
          # that reduce P(STOP|s) to near 0, which is undesirable. In this case, 
          # we allow STOPs if selected naturally by the policy or it's the only 
          # action on a trajectory (a trajectory MUST 
          # have at least one action). All other STOPs we just forego
          # to prevent these harmful gradient updates
          break
      elif PREMATURE_BREAK and not isStop(a) and iou < GOAL_IOU  and prev_iou > GOAL_IOU:
        # TRAJECTORY IS WORSENING
        print("             |->> IOU declining: {0}:{1} -> {2}:{3}."
                  .format(prev_bbox, prev_iou, bbox, iou))
        print("             |->> Overriding with STOP"
                .format(iou))
        a, bbox = 8, prev_bbox
      
      a_prob = probs[a] 
      print("   \x1b[33m|->> #{0}/t={1}-th Action selection: {2}/{3} (P(a|s) = {4})\x1b[0m"
                .format(len(actions_taken), t, a, human_readable_action(a).upper(), 
                        np.around(a_prob, decimals=3)))
      print("      |->> Bounding box moves to: {0}"
                .format(bbox))
      print("         |->> Action Probabilities (Rounded): {0}, argmax={1}"
              .format(np.around(probs.numpy(), decimals=4), np.argmax(probs)))
      print("         |->> Action Probabilities (RAW): {0}, argmax={1}"
              .format(probs.numpy(), np.argmax(probs)))

      if VERBOSE:
        print("         |->> Overwriting action in buffer {0}"
            .format(model.getPrettyActionHistory() if VERBOSE else ""))
        
      action_probs.append(probs)
      actions_taken.append(a)
      model.updateActionHistory(a)
      bboxes.append(tuple(bbox))  
      patch = getPatch(img, bbox)      

      # Stopping condition
      if isStop(a):
        print("         |->> Hit a STOP on the {0}-th action!".format(t))
        break  
      
      t += 1

    print("    \x1b[31m|->> Completed tracking\x1b[0m")
    
    return action_probs, actions_taken, bboxes, t

# %% [markdown]
# ### Single Training Loop

# %%
VERBOSE = False

def train(model: ADNET, opt: tf.keras.optimizers.Optimizer, 
          dataset: str, start_frame: int, end_frame: int, 
          retry_count: int=N_RETRIES) -> float:
  '''
  Run training for a model on a frame sequence {start_frame, end_frame} 
  n_retries times.
  :param: dataset: is the dataset path to train from
  :param: retry_count: number of times to train on the frame sequence. 
  :return: returns the model and average loss
  '''

  gt = get_ground_truths("%s/groundtruth_rect.txt" % dataset)
  frames = sorted(glob.glob(os.path.join('%s/img' % dataset, '*.jpg'))) 
  loss = 0.0

  train_vars = model.trainable_variables
  accum_gradient = [tf.zeros_like(this_var) for this_var in train_vars]
  for i in range(retry_count):
    print("\n\x1b[36m####################### EPISODE # {0} ############################\x1b[0m".format(i+1))
    bbox = gt[start_frame]
    print("Starting bounding box={3} for {0}'s frames (index: {1})\nsrc:{2}\ntarget:{3}.".format(
        dataset, i, frames[start_frame], frames[end_frame], bbox))
    
    t = 1    
    model.clearActionHistory()
    for i in range(start_frame+1, end_frame+1):
      with tf.GradientTape() as tape:
        target_bbox = gt[i]
        prev_bbox = np.array(bbox, copy=True)

        print("\x1b[34m>> Attempting to reach frame {0} with src: {1} and target: {2}\x1b[0m"
            .format(i, np.array2string(bbox, separator=', '), 
                    np.array2string(target_bbox, separator=', ')))
        img = getFrame(frames[i])
        action_probs, taken_actions, bboxes, t = tracking(model, img, 
                                                          bbox, t, target_bbox)
        bbox = np.array(bboxes[-1])


        frame_losses = seqLosses(action_probs, taken_actions, bboxes, target_bbox)
        total_frame_loss = tf.reduce_sum(frame_losses)
        
        loss += np.sum(total_frame_loss.numpy())
        print("{0}>> Total frame loss: {1}\x1b[0m".format(
              "\x1b[92m" if total_frame_loss > 0 else "\x1b[31m", 
              total_frame_loss))

      gradients = tape.gradient(total_frame_loss, train_vars)
      accum_gradient = [(acum_grad + grad) 
                        for acum_grad, grad in zip(accum_gradient, gradients)]

    print("Final bounding box: {0} reached in {1} timesteps (originating from {2}). Target was {3}"
          .format(bbox, t, np.array(gt[start_frame]), np.array(gt[end_frame])))
    print("\n\x1b[36m############# END EPISODE # {0} in t={1} timesteps ################\x1b[0m"
          .format(i+1, t))
    

  print("Avg Loss Across Trajectories: {0}\x1b[0m".format(
      "\x1b[92m" if loss > 0 else "\x1b[31m"))  
  
  
  
  accum_gradient = [g / retry_count if GRAD_ACCUM_SCHEME == "avg" else g 
                    for g in accum_gradient]
  for i in range(len(accum_gradient)):
      print("Layer Name: {}, GRAD NORM = {}".format(
      adnet_model.trainable_variables[i].name, tf.norm(accum_gradient[i])))
  opt.apply_gradients(zip(accum_gradient, model.trainable_variables))
  return model, loss / retry_count

# %% [markdown]
# ### Epoch Training Loops

# %%
def epochs_train(model: ADNET, opt: tf.keras.optimizers.Optimizer, 
                 datasets: List[str], 
                 epochs: int=1, retry_count: int=1, action_strategy: str="max",
                 seq_length: int=10, randomize: bool=RANDOMIZE_TRAINING):

  print("TRAINING ON: {0}".format(datasets))
  # Collect list of datasets & trainable frames
  dataset_frames = []
  for d in datasets:
    frames = sorted(glob.glob(os.path.join('%s/img' % d, '*.jpg')))
    frames = list(range(len(frames) - L))
    for f in frames:
      dataset_frames.append((d, f))
  if randomize: random.shuffle(dataset_frames)

  # Train for n epochs
  losses = {}
  bad_data_log = []
  for e in range(epochs):
    epoch_loss = []
    
    for i, d_frame in enumerate(dataset_frames):
      d, start_frame = d_frame
      end_frame = start_frame + seq_length

      print("\n\n#############################################")
      print("Dataset={0}".format(d))
      print("#################################################")
      adnet_model, l = train(model, opt, d, start_frame, end_frame, 
                             retry_count=retry_count)
      epoch_loss.append(l)
      print("#################################################")
      print("#################################################")
      
    losses[e] = epoch_loss

  print("Finished Training On: {0}".format(datasets))
  return model, losses

# %% [markdown]
# # Training Procedure

# %%
# %reload_ext autoreload

# %%
adnet_model = ADNET()
adnet_model.build()
WEIGHTS_PATH = "yifanweights.mat"
weights = hdf5storage.loadmat(WEIGHTS_PATH)
adnet_model = setWeights(adnet_model,weights,weights)
adnet_model.layers[-3].trainable=False

# %% [markdown]
# ### To reload saved weights

# %%
SAVED_MODEL_PATH = "derek_models/19-12-2021_060516"
loaded_model = tf.keras.models.load_model(SAVED_MODEL_PATH, 
                                         custom_objects={"ADNET": ADNET}, 
                                          compile=False)
loaded_model.compile(optimizer=Adam(learning_rate=LEARNING_RATE))
adnet_model.set_weights(loaded_model.get_weights())

# %%
N_VIDEOS = 3
datasets = np.random.choice(len(ALL_DATASETS_LIST), size=N_VIDEOS, replace=False)
datasets = list(map(lambda rand_idx: ALL_DATASETS_LIST[rand_idx], datasets))
print("Training on datasets: {0}".format(datasets))
# Out:
# Training on datasets: ['adnet_datasets/OTB/Rubik', 'adnet_datasets/OTB/Girl', 'adnet_datasets/OTB/Shaking']

# %%
model, losses = epochs_train(adnet_model, Adam(learning_rate=LEARNING_RATE), 
                             datasets, epochs=N_EPOCHS, retry_count=N_RETRIES, 
                             randomize=RANDOMIZE_TRAINING)
# Out:
# Streaming output truncated to the last 5000 lines.
#    |->> #1/t=2-th Action selection: 7/2X DOWN (P(a|s) = 0.08900000154972076)
#       |->> Bounding box moves to: [318 144  71  63]
#          |->> Action Probabilities (Rounded): [0.0999 0.0826 0.0811 0.0861 0.088  0.0826 0.0923 0.0887 0.1263 0.0824
#  0.0901], argmax=8
#          |->> Action Probabilities (RAW): [0.09985967 0.08256058 0.08109453 0.08610895 0.08799328 0.0826149
#  0.09233095 0.08869702 0.1262825  0.08235925 0.0900984 ], argmax=8
#    |->> #2/t=3-th Action selection: 10/SCALE UP (P(a|s) = 0.08699999749660492)
#       |->> Bounding box moves to: [316 143  73  65]
#          |->> Action Probabilities (Rounded): [0.0848 0.0816 0.0922 0.0828 0.0886 0.0853 0.0892 0.0844 0.1414 0.0825
#  0.0873], argmax=8
#          |->> Action Probabilities (RAW): [0.08478132 0.08158934 0.09216167 0.08280867 0.08858409 0.08534244
#  0.08915517 0.08441397 0.14135094 0.08253238 0.08727995], argmax=8
#    |->> #3/t=4-th Action selection: 3/2X RIGHT (P(a|s) = 0.08500000089406967)
#       |->> Bounding box moves to: [320 143  73  65]
#          |->> Action Probabilities (Rounded): [0.0864 0.0775 0.0855 0.085  0.0883 0.081  0.0869 0.0827 0.1614 0.0831
#  0.0822], argmax=8
#          |->> Action Probabilities (RAW): [0.08643619 0.0775134  0.08551144 0.08501621 0.08826657 0.08102622
#  0.08689237 0.08268345 0.16135652 0.08309651 0.08220118], argmax=8
#    |->> #4/t=5-th Action selection: 5/2X UP (P(a|s) = 0.07699999958276749)
#       |->> Bounding box moves to: [320 141  73  65]
#          |->> Action Probabilities (Rounded): [0.0847 0.0844 0.0838 0.077  0.0831 0.0774 0.0909 0.0809 0.1764 0.0776
#  0.0839], argmax=8
#          |->> Action Probabilities (RAW): [0.08466446 0.0843571  0.083819   0.07697827 0.08307678 0.07739528
#  0.09094163 0.08087718 0.17643286 0.07757605 0.0838814 ], argmax=8
# |->> Revisiting bbox: [320 141  73  65]. ACtion 8 did nothing. Breaking action sequence
#    |->> Trajectory ending is FORCED
#     |->> Completed tracking
# >> Calculating frame loss : [316, 142,  71,  63] -> [320, 141,  73,  65] (Target was [315, 146,  70,  62])
#    |->> t=1 Diff-Reward (-0.045) for RIGHT:bbox transition: [316, 142,  71,  63] -> [318, 142,  71,  63] w/ P(a|s)=0.09168218076229095 and iou=0.8133744855967078 and reward=-0.04512403823290001 and discount=1.0
#    |->> t=2 Diff-Reward (0.051) for 2X DOWN:bbox transition: [318, 142,  71,  63] -> [318, 144,  71,  63] w/ P(a|s)=0.08869702368974686 and iou=0.8647905205247567 and reward=0.051416034928048915 and discount=1.0
#    |->> t=3 Diff-Reward (0.025) for SCALE UP:bbox transition: [318, 144,  71,  63] -> [316, 143,  73,  65] w/ P(a|s)=0.08727994561195374 and iou=0.8899521531100478 and reward=0.025161632585291138 and discount=1.0
#    |->> t=4 Diff-Reward (-0.093) for 2X RIGHT:bbox transition: [316, 143,  73,  65] -> [320, 143,  73,  65] w/ P(a|s)=0.08501621335744858 and iou=0.7972304648862513 and reward=-0.09272168822379656 and discount=1.0
#    |->> t=5 Diff-Reward (1.0) for 2X UP:bbox transition: [320, 143,  73,  65] -> [320, 141,  73,  65] w/ P(a|s)=0.07739528268575668 and iou=0.7521697203471552 and reward=1.0 and discount=1.0
#    |->> Assigned losses: [-0.10782061  0.12455684  0.06136003 -0.22855093  2.5588295 ]
# >> Total frame loss: 2.408374786376953
# >> Attempting to reach frame 19 with src: [320, 141,  73,  65] and target: [317, 150,  70,  62]
# Frame path: adnet_datasets/OTB/Rubik/img/0020.jpg
# |->> Beginning tracking for bbox:[320 141  73  65]
#    |->> #0/t=6-th Action selection: 7/2X DOWN (P(a|s) = 0.08500000089406967)
#       |->> Bounding box moves to: [320 143  73  65]
#          |->> Action Probabilities (Rounded): [0.0823 0.0718 0.0805 0.076  0.0815 0.071  0.0893 0.0853 0.2095 0.0735
#  0.0793], argmax=8
#          |->> Action Probabilities (RAW): [0.08228918 0.07180653 0.08054963 0.07597554 0.08148033 0.07099421
#  0.08934765 0.08531628 0.2094648  0.07346176 0.07931405], argmax=8
# |->> Revisiting bbox: [320 143  73  65]. ACtion 8 did nothing. Breaking action sequence
#    |->> Trajectory ending is FORCED
#     |->> Completed tracking
# >> Calculating frame loss : [320, 141,  73,  65] -> [320, 143,  73,  65] (Target was [317, 150,  70,  62])
#    |->> t=1 Diff-Reward (1.0) for 2X DOWN:bbox transition: [320, 141,  73,  65] -> [320, 143,  73,  65] w/ P(a|s)=0.08531627804040909 and iou=0.7474514329678784 and reward=1.0 and discount=1.0
#    |->> Assigned losses: [2.46139]
# >> Total frame loss: 2.4613900184631348
# >> Attempting to reach frame 20 with src: [320, 143,  73,  65] and target: [316, 155,  68,  62]
# Frame path: adnet_datasets/OTB/Rubik/img/0021.jpg
# |->> Beginning tracking for bbox:[320 143  73  65]
#    |->> #0/t=7-th Action selection: 5/2X UP (P(a|s) = 0.0729999989271164)
#       |->> Bounding box moves to: [320 141  73  65]
#          |->> Action Probabilities (Rounded): [0.0762 0.0696 0.084  0.0716 0.0796 0.0726 0.0841 0.0785 0.2341 0.0716
#  0.0781], argmax=8
#          |->> Action Probabilities (RAW): [0.07619075 0.06958956 0.08402124 0.07160703 0.07958104 0.07256629
#  0.08413734 0.07849213 0.23409724 0.07158659 0.07813077], argmax=8
#    |->> #1/t=8-th Action selection: 6/DOWN (P(a|s) = 0.08100000023841858)
#       |->> Bounding box moves to: [320 142  73  65]
#          |->> Action Probabilities (Rounded): [0.072  0.0685 0.0762 0.0709 0.0731 0.0632 0.0808 0.0796 0.2761 0.0654
#  0.0742], argmax=8
#          |->> Action Probabilities (RAW): [0.07196941 0.06851245 0.07620835 0.07091755 0.07308571 0.06316439
#  0.0808017  0.07960571 0.2761146  0.06544023 0.07417988], argmax=8
#    |->> #2/t=9-th Action selection: 7/2X DOWN (P(a|s) = 0.07500000298023224)
#       |->> Bounding box moves to: [320 144  73  65]
#          |->> Action Probabilities (Rounded): [0.0711 0.0616 0.0753 0.0664 0.0758 0.0626 0.0801 0.0749 0.302  0.0593
#  0.0709], argmax=8
#          |->> Action Probabilities (RAW): [0.0711371  0.0615613  0.07533136 0.06638124 0.07576358 0.06264994
#  0.08012862 0.0748828  0.30195874 0.05931552 0.0708898 ], argmax=8
#    |->> #3/t=10-th Action selection: 3/2X RIGHT (P(a|s) = 0.06700000166893005)
#       |->> Bounding box moves to: [324 144  73  65]
#          |->> Action Probabilities (Rounded): [0.0648 0.0577 0.0728 0.0667 0.0678 0.0612 0.0692 0.0657 0.3497 0.0598
#  0.0645], argmax=8
#          |->> Action Probabilities (RAW): [0.06482687 0.05771831 0.0728333  0.06669214 0.06779768 0.061196
#  0.06923602 0.06572881 0.34973243 0.05978462 0.06445383], argmax=8
# |->> Revisiting bbox: [324 144  73  65]. ACtion 8 did nothing. Breaking action sequence
#    |->> Trajectory ending is FORCED
#     |->> Completed tracking
# >> Calculating frame loss : [320, 143,  73,  65] -> [324, 144,  73,  65] (Target was [316, 155,  68,  62])
#    |->> t=1 Diff-Reward (-0.036) for 2X UP:bbox transition: [320, 143,  73,  65] -> [320, 141,  73,  65] w/ P(a|s)=0.07256629317998886 and iou=0.5729331226961558 and reward=-0.036152889155164014 and discount=1.0
#    |->> t=2 Diff-Reward (0.018) for DOWN:bbox transition: [320, 141,  73,  65] -> [320, 142,  73,  65] w/ P(a|s)=0.08080169558525085 and iou=0.5908041895970175 and reward=0.01787106690086171 and discount=1.0
#    |->> t=3 Diff-Reward (0.037) for 2X DOWN:bbox transition: [320, 142,  73,  65] -> [320, 144,  73,  65] w/ P(a|s)=0.07488279789686203 and iou=0.6277929155313352 and reward=0.03698872593431768 and discount=1.0
#    |->> t=4 Diff-Reward (-1.0) for 2X RIGHT:bbox transition: [320, 144,  73,  65] -> [324, 144,  73,  65] w/ P(a|s)=0.06669214367866516 and iou=0.5663345568956476 and reward=-1.0 and discount=1.0
#    |->> Assigned losses: [-0.09483824  0.04495927  0.09586854 -2.707668  ]
# >> Total frame loss: -2.6616785526275635
# >> Attempting to reach frame 21 with src: [324, 144,  73,  65] and target: [312, 156,  70,  62]
# Frame path: adnet_datasets/OTB/Rubik/img/0022.jpg
# |->> Beginning tracking for bbox:[324 144  73  65]
# |->> Revisiting bbox: [324 144  73  65]. ACtion 8 did nothing. Breaking action sequence
#    |->> Trajectory ending is FORCED
#    |->> #0/t=11-th Action selection: 8/STOP (P(a|s) = 0.39500001072883606)
#       |->> Bounding box moves to: [324 144  73  65]
#          |->> Action Probabilities (Rounded): [0.0653 0.0582 0.0627 0.0575 0.0656 0.0534 0.0655 0.0578 0.3951 0.0527
#  0.0663], argmax=8
#          |->> Action Probabilities (RAW): [0.06530928 0.05821844 0.0626851  0.05745453 0.06557762 0.05337328
#  0.06554472 0.05783477 0.3950584  0.05265231 0.06629156], argmax=8
#          |->> Hit a STOP on the 11-th action!
#     |->> Completed tracking
# >> Calculating frame loss : [324, 144,  73,  65] -> [324, 144,  73,  65] (Target was [312, 156,  70,  62])
#    |->> t=1 Stop-Reward (-1.0) for STOP:bbox transition: [324, 144,  73,  65] -> [324, 144,  73,  65] w/ P(a|s)=0.39505839347839355 and iou=0.5113957744135751 and reward=-1.0 and discount=1.0
#    |->> Assigned losses: [-0.92872167]
# >> Total frame loss: -0.9287216663360596
# >> Attempting to reach frame 22 with src: [324, 144,  73,  65] and target: [316, 152,  67,  68]
# Frame path: adnet_datasets/OTB/Rubik/img/0023.jpg
# |->> Beginning tracking for bbox:[324 144  73  65]
# |->> Revisiting bbox: [324 144  73  65]. ACtion 8 did nothing. Breaking action sequence
#    |->> Trajectory ending is FORCED
#    |->> #0/t=11-th Action selection: 8/STOP (P(a|s) = 0.38600000739097595)
#       |->> Bounding box moves to: [324 144  73  65]
#          |->> Action Probabilities (Rounded): [0.0636 0.0593 0.0636 0.058  0.063  0.0565 0.0687 0.0624 0.3856 0.0542
#  0.065 ], argmax=8
#          |->> Action Probabilities (RAW): [0.0636448  0.05925947 0.06357263 0.05800404 0.06300978 0.05652859
#  0.06872278 0.06244139 0.3856184  0.05420439 0.0649938 ], argmax=8
#          |->> Hit a STOP on the 11-th action!
#     |->> Completed tracking
# >> Calculating frame loss : [324, 144,  73,  65] -> [324, 144,  73,  65] (Target was [316, 152,  67,  68])
#    |->> t=1 Stop-Reward (-1.0) for STOP:bbox transition: [324, 144,  73,  65] -> [324, 144,  73,  65] w/ P(a|s)=0.3856183886528015 and iou=0.5663523071741327 and reward=-1.0 and discount=1.0
#    |->> Assigned losses: [-0.952907]
# >> Total frame loss: -0.9529070258140564
# >> Attempting to reach frame 23 with src: [324, 144,  73,  65] and target: [310, 155,  72,  62]
# Frame path: adnet_datasets/OTB/Rubik/img/0024.jpg
# |->> Beginning tracking for bbox:[324 144  73  65]
# |->> Revisiting bbox: [324 144  73  65]. ACtion 8 did nothing. Breaking action sequence
#    |->> Trajectory ending is FORCED
#    |->> #0/t=11-th Action selection: 8/STOP (P(a|s) = 0.3790000081062317)
#       |->> Bounding box moves to: [324 144  73  65]
#          |->> Action Probabilities (Rounded): [0.0647 0.0553 0.0647 0.0588 0.0659 0.0555 0.0734 0.0647 0.379  0.053
#  0.065 ], argmax=8
#          |->> Action Probabilities (RAW): [0.06466224 0.05532865 0.06474484 0.05880487 0.06585798 0.05550796
#  0.07335671 0.06473903 0.37899098 0.05302228 0.06498448], argmax=8
#          |->> Hit a STOP on the 11-th action!
#     |->> Completed tracking
# >> Calculating frame loss : [324, 144,  73,  65] -> [324, 144,  73,  65] (Target was [310, 155,  72,  62])
#    |->> t=1 Stop-Reward (-1.0) for STOP:bbox transition: [324, 144,  73,  65] -> [324, 144,  73,  65] w/ P(a|s)=0.3789909780025482 and iou=0.5153858811913773 and reward=-1.0 and discount=1.0
#    |->> Assigned losses: [-0.97024286]
# >> Total frame loss: -0.9702428579330444
# >> Attempting to reach frame 24 with src: [324, 144,  73,  65] and target: [313, 159,  69,  61]
# Frame path: adnet_datasets/OTB/Rubik/img/0025.jpg
# |->> Beginning tracking for bbox:[324 144  73  65]
#    |->> #0/t=11-th Action selection: 7/2X DOWN (P(a|s) = 0.06300000101327896)
#       |->> Bounding box moves to: [324 146  73  65]
#          |->> Action Probabilities (Rounded): [0.0603 0.0581 0.0604 0.0563 0.0596 0.0554 0.0692 0.0635 0.4016 0.0503
#  0.0656], argmax=8
#          |->> Action Probabilities (RAW): [0.06028708 0.05808181 0.06035402 0.05628119 0.05955927 0.05537447
#  0.06915278 0.06347726 0.40158692 0.05027326 0.06557187], argmax=8
#    |->> #1/t=12-th Action selection: 7/2X DOWN (P(a|s) = 0.05900000035762787)
#       |->> Bounding box moves to: [324 148  73  65]
#          |->> Action Probabilities (Rounded): [0.0562 0.0513 0.0607 0.0583 0.0614 0.0565 0.0649 0.0591 0.4242 0.0492
#  0.0582], argmax=8
#          |->> Action Probabilities (RAW): [0.05624187 0.05129637 0.06067507 0.05828942 0.06139043 0.05654216
#  0.06489752 0.05906299 0.42423066 0.04921956 0.05815397], argmax=8
# |->> Revisiting bbox: [324 148  73  65]. ACtion 8 did nothing. Breaking action sequence
#    |->> Trajectory ending is FORCED
#     |->> Completed tracking
# >> Calculating frame loss : [324, 144,  73,  65] -> [324, 148,  73,  65] (Target was [313, 159,  69,  61])
#    |->> t=1 Diff-Reward (0.029) for 2X DOWN:bbox transition: [324, 144,  73,  65] -> [324, 146,  73,  65] w/ P(a|s)=0.06347726285457611 and iou=0.5079151229370158 and reward=0.028892988810818254 and discount=1.0
#    |->> t=2 Diff-Reward (-1.0) for 2X DOWN:bbox transition: [324, 146,  73,  65] -> [324, 148,  73,  65] w/ P(a|s)=0.05906299129128456 and iou=0.5379594641016833 and reward=-1.0 and discount=1.0
#    |->> Assigned losses: [ 0.07966009 -2.8291507 ]
# >> Total frame loss: -2.74949049949646
# >> Attempting to reach frame 25 with src: [324, 148,  73,  65] and target: [314, 157,  67,  62]
# Frame path: adnet_datasets/OTB/Rubik/img/0026.jpg
# |->> Beginning tracking for bbox:[324 148  73  65]
#    |->> #0/t=13-th Action selection: 4/UP (P(a|s) = 0.05999999865889549)
#       |->> Bounding box moves to: [324 147  73  65]
#          |->> Action Probabilities (Rounded): [0.0572 0.0518 0.066  0.0587 0.0605 0.0578 0.0598 0.0544 0.4253 0.05
#  0.0586], argmax=8
#          |->> Action Probabilities (RAW): [0.057206   0.05180162 0.06595347 0.05867904 0.06045928 0.0577607
#  0.05981608 0.05440874 0.42529842 0.05001511 0.05860154], argmax=8
# |->> Revisiting bbox: [324 147  73  65]. ACtion 8 did nothing. Breaking action sequence
#    |->> Trajectory ending is FORCED
#     |->> Completed tracking
# >> Calculating frame loss : [324, 148,  73,  65] -> [324, 147,  73,  65] (Target was [314, 157,  67,  62])
#    |->> t=1 Diff-Reward (-1.0) for UP:bbox transition: [324, 148,  73,  65] -> [324, 147,  73,  65] w/ P(a|s)=0.060459282249212265 and iou=0.5438931297709924 and reward=-1.0 and discount=1.0
#    |->> Assigned losses: [-2.8057852]
# >> Total frame loss: -2.8057851791381836
# >> Attempting to reach frame 26 with src: [324, 147,  73,  65] and target: [313, 158,  70,  62]
# Frame path: adnet_datasets/OTB/Rubik/img/0027.jpg
# |->> Beginning tracking for bbox:[324 147  73  65]
#    |->> #0/t=14-th Action selection: 5/2X UP (P(a|s) = 0.057999998331069946)
#       |->> Bounding box moves to: [324 145  73  65]
#          |->> Action Probabilities (Rounded): [0.059  0.0523 0.0625 0.0606 0.059  0.0576 0.0643 0.0572 0.4173 0.0495
#  0.0607], argmax=8
#          |->> Action Probabilities (RAW): [0.05902006 0.05228197 0.0624576  0.06057854 0.05895048 0.05760755
#  0.06434932 0.05723861 0.41729036 0.04953735 0.06068816], argmax=8
#    |->> #1/t=15-th Action selection: 1/2X LEFT (P(a|s) = 0.050999999046325684)
#       |->> Bounding box moves to: [320 145  73  65]
#          |->> Action Probabilities (Rounded): [0.0582 0.0509 0.064  0.0601 0.0597 0.0542 0.0657 0.0607 0.4165 0.0485
#  0.0615], argmax=8
#          |->> Action Probabilities (RAW): [0.05815045 0.05093435 0.06400628 0.06009609 0.05970438 0.05416282
#  0.06566947 0.06073435 0.41651347 0.04852464 0.06150366], argmax=8
#    |->> #2/t=16-th Action selection: 7/2X DOWN (P(a|s) = 0.05999999865889549)
#       |->> Bounding box moves to: [320 147  73  65]
#          |->> Action Probabilities (Rounded): [0.0591 0.0485 0.0669 0.0657 0.0586 0.0513 0.0699 0.0602 0.4121 0.0474
#  0.0601], argmax=8
#          |->> Action Probabilities (RAW): [0.05910433 0.048524   0.06692915 0.06569209 0.05864257 0.05129497
#  0.06992488 0.06022874 0.41207704 0.04744159 0.06014071], argmax=8
#    |->> #3/t=17-th Action selection: 4/UP (P(a|s) = 0.061000000685453415)
#       |->> Bounding box moves to: [320 146  73  65]
#          |->> Action Probabilities (Rounded): [0.0573 0.0508 0.0691 0.0635 0.0614 0.0563 0.0662 0.061  0.4058 0.0502
#  0.0583], argmax=8
#          |->> Action Probabilities (RAW): [0.05733279 0.05083634 0.06909195 0.06346021 0.06144878 0.05631398
#  0.06622732 0.06098934 0.40579847 0.05019499 0.05830582], argmax=8
#    |->> #4/t=18-th Action selection: 2/RIGHT (P(a|s) = 0.07199999690055847)
#       |->> Bounding box moves to: [322 146  73  65]
#          |->> Action Probabilities (Rounded): [0.0597 0.0505 0.0721 0.0654 0.0618 0.0584 0.0718 0.0616 0.3852 0.0516
#  0.0619], argmax=8
#          |->> Action Probabilities (RAW): [0.05967903 0.05052466 0.07213325 0.06536778 0.06179528 0.05841577
#  0.07184862 0.06157677 0.38515463 0.05159137 0.06191284], argmax=8
#    |->> #5/t=19-th Action selection: 2/RIGHT (P(a|s) = 0.06199999898672104)
#       |->> Bounding box moves to: [324 146  73  65]
#          |->> Action Probabilities (Rounded): [0.0695 0.0522 0.0619 0.0633 0.0611 0.0579 0.0704 0.0624 0.3864 0.0506
#  0.0644], argmax=8
#          |->> Action Probabilities (RAW): [0.06945289 0.05219689 0.06191352 0.06325221 0.06106531 0.05789559
#  0.07039823 0.06239498 0.3864306  0.0506059  0.06439388], argmax=8
# |->> Revisiting bbox: [322 146  73  65]. ACtion 0 did nothing. Breaking action sequence
#    |->> Trajectory ending is FORCED
#     |->> Completed tracking
# >> Calculating frame loss : [324, 147,  73,  65] -> [324, 146,  73,  65] (Target was [313, 158,  70,  62])
#    |->> t=1 Diff-Reward (-0.03) for 2X UP:bbox transition: [324, 147,  73,  65] -> [324, 145,  73,  65] w/ P(a|s)=0.05760754644870758 and iou=0.5098886488283197 and reward=-0.0302028921108225 and discount=1.0
#    |->> t=2 Diff-Reward (0.054) for 2X LEFT:bbox transition: [324, 145,  73,  65] -> [320, 145,  73,  65] w/ P(a|s)=0.05093434825539589 and iou=0.5639524875193666 and reward=0.054063838691046806 and discount=1.0
#    |->> t=3 Diff-Reward (0.035) for 2X DOWN:bbox transition: [320, 145,  73,  65] -> [320, 147,  73,  65] w/ P(a|s)=0.06022874265909195 and iou=0.5986274854830196 and reward=0.03467499796365303 and discount=1.0
#    |->> t=4 Diff-Reward (-0.018) for UP:bbox transition: [320, 147,  73,  65] -> [320, 146,  73,  65] w/ P(a|s)=0.06144878268241882 and iou=0.5810998955795336 and reward=-0.01752758990348602 and discount=1.0
#    |->> t=5 Diff-Reward (-0.029) for RIGHT:bbox transition: [320, 146,  73,  65] -> [322, 146,  73,  65] w/ P(a|s)=0.07213325053453445 and iou=0.5524606971975393 and reward=-0.028639198381994246 and discount=1.0
#    |->> t=6 Diff-Reward (-1.0) for RIGHT:bbox transition: [322, 146,  73,  65] -> [324, 146,  73,  65] w/ P(a|s)=0.061913516372442245 and iou=0.5248405505203089 and reward=-1.0 and discount=1.0
#    |->> Assigned losses: [-0.08620212  0.16095981  0.09742307 -0.04889411 -0.07529934 -2.7820168 ]
# >> Total frame loss: -2.7340292930603027
# >> Attempting to reach frame 27 with src: [324, 146,  73,  65] and target: [313, 160,  68,  62]
# Frame path: adnet_datasets/OTB/Rubik/img/0028.jpg
# |->> Beginning tracking for bbox:[324 146  73  65]
# |->> Revisiting bbox: [324 146  73  65]. ACtion 8 did nothing. Breaking action sequence
#    |->> Trajectory ending is FORCED
#    |->> #0/t=20-th Action selection: 8/STOP (P(a|s) = 0.38199999928474426)
#       |->> Bounding box moves to: [324 146  73  65]
#          |->> Action Probabilities (Rounded): [0.0713 0.0532 0.0611 0.0631 0.0652 0.0539 0.0704 0.0629 0.3818 0.0516
#  0.0655], argmax=8
#          |->> Action Probabilities (RAW): [0.07126758 0.05323483 0.06109162 0.06307128 0.06520866 0.05394154
#  0.07036923 0.06290648 0.3818085  0.0516188  0.06548152], argmax=8
#          |->> Hit a STOP on the 20-th action!
#     |->> Completed tracking
# >> Calculating frame loss : [324, 146,  73,  65] -> [324, 146,  73,  65] (Target was [313, 160,  68,  62])
#    |->> t=1 Stop-Reward (-1.0) for STOP:bbox transition: [324, 146,  73,  65] -> [324, 146,  73,  65] w/ P(a|s)=0.38180848956108093 and iou=0.4801783944499504 and reward=-1.0 and discount=1.0
#    |->> Assigned losses: [-0.96283615]
# >> Total frame loss: -0.9628361463546753
# Final bounding box: [324 146  73  65] reached in 20 timesteps (originating from [316 142  71  63]). Target was [313 160  68  62]
#
# ############# END EPISODE # 28 in t=20 timesteps ################
# Avg Loss Across Trajectories:
# Layer Name: conv_1/kernel:0, GRAD NORM = 0.0
# Layer Name: conv_1/bias:0, GRAD NORM = 0.0
# Layer Name: conv_2/kernel:0, GRAD NORM = 0.0
# Layer Name: conv_2/bias:0, GRAD NORM = 0.0
# Layer Name: conv_3/kernel:0, GRAD NORM = 0.0
# Layer Name: conv_3/bias:0, GRAD NORM = 0.0
# Layer Name: fc1/kernel:0, GRAD NORM = 0.0
# Layer Name: fc1/bias:0, GRAD NORM = 0.0
# Layer Name: fc2/kernel:0, GRAD NORM = 0.0
# Layer Name: fc2/bias:0, GRAD NORM = 0.0
# Layer Name: fc3/kernel:0, GRAD NORM = 8.079019546508789
# Layer Name: fc3/bias:0, GRAD NORM = 2.35103440284729
# #################################################
# #################################################
#
#
# #############################################
# Dataset=adnet_datasets/OTB/Rubik
# #################################################
#
# ####################### EPISODE # 1 ############################
# Starting bounding box=adnet_datasets/OTB/Rubik/img/0029.jpg for adnet_datasets/OTB/Rubik's frames (index: 0)
# src:adnet_datasets/OTB/Rubik/img/0019.jpg
# target:adnet_datasets/OTB/Rubik/img/0029.jpg.
# >> Attempting to reach frame 19 with src: [315, 146,  70,  62] and target: [317, 150,  70,  62]
# Frame path: adnet_datasets/OTB/Rubik/img/0020.jpg
# |->> Beginning tracking for bbox:[315 146  70  62]
#    |->> #0/t=1-th Action selection: 1/2X LEFT (P(a|s) = 0.08399999886751175)
#       |->> Bounding box moves to: [311 146  70  62]
#          |->> Action Probabilities (Rounded): [0.0888 0.0844 0.0917 0.0892 0.0892 0.0847 0.0922 0.0898 0.1128 0.0865
#  0.0907], argmax=8
#          |->> Action Probabilities (RAW): [0.08878215 0.08442038 0.09168223 0.0892024  0.08920832 0.08468887
#  0.09219784 0.08978289 0.11283846 0.08647115 0.09072537], argmax=8
#    |->> #1/t=2-th Action selection: 2/RIGHT (P(a|s) = 0.09300000220537186)
#       |->> Bounding box moves to: [313 146  70  62]
#          |->> Action Probabilities (Rounded): [0.0852 0.076  0.0931 0.0958 0.0883 0.081  0.0917 0.0876 0.1293 0.0834
#  0.0884], argmax=8
#          |->> Action Probabilities (RAW): [0.08516838 0.07602074 0.09310658 0.09581266 0.08834618 0.08102855
#  0.09172595 0.08764692 0.12933324 0.08338787 0.08842294], argmax=8
#    |->> #2/t=3-th Action selection: 4/UP (P(a|s) = 0.0860000029206276)
#       |->> Bounding box moves to: [313 145  70  62]
#          |->> Action Probabilities (Rounded): [0.0943 0.0753 0.0825 0.0895 0.0862 0.0799 0.0916 0.0882 0.1455 0.0791
#  0.0879], argmax=8
#          |->> Action Probabilities (RAW): [0.09428404 0.07534815 0.08253774 0.08953979 0.08621806 0.07986057
#  0.09157454 0.08817622 0.1455028  0.07907101 0.08788709], argmax=8
#    |->> #3/t=4-th Action selection: 7/2X DOWN (P(a|s) = 0.08900000154972076)
#       |->> Bounding box moves to: [313 147  70  62]
#          |->> Action Probabilities (Rounded): [0.08   0.0751 0.0927 0.0847 0.0823 0.0756 0.0957 0.0893 0.1638 0.0766
#  0.0839], argmax=8
#          |->> Action Probabilities (RAW): [0.08004384 0.07514605 0.09272657 0.08473899 0.08232948 0.07564344
#  0.0957226  0.08930483 0.16383432 0.07658358 0.08392635], argmax=8
# |->> Revisiting bbox: [313 146  70  62]. ACtion 4 did nothing. Breaking action sequence
#    |->> Trajectory ending is FORCED
#     |->> Completed tracking
# >> Calculating frame loss : [315, 146,  70,  62] -> [313, 147,  70,  62] (Target was [317, 150,  70,  62])
#    |->> t=1 Diff-Reward (-0.086) for 2X LEFT:bbox transition: [315, 146,  70,  62] -> [311, 146,  70,  62] w/ P(a|s)=0.08442037552595139 and iou=0.7471819645732689 and reward=-0.08558830569700138 and discount=1.0
#    |->> t=2 Diff-Reward (0.042) for RIGHT:bbox transition: [311, 146,  70,  62] -> [313, 146,  70,  62] w/ P(a|s)=0.09310657531023026 and iou=0.7889530090684254 and reward=0.04177104449515645 and discount=1.0
#    |->> t=3 Diff-Reward (-0.024) for UP:bbox transition: [313, 146,  70,  62] -> [313, 145,  70,  62] w/ P(a|s)=0.08621805906295776 and iou=0.7649450996339976 and reward=-0.024007909434427765 and discount=1.0
#    |->> t=4 Diff-Reward (1.0) for 2X DOWN:bbox transition: [313, 145,  70,  62] -> [313, 147,  70,  62] w/ P(a|s)=0.0893048346042633 and iou=0.8136230672795653 and reward=1.0 and discount=1.0
#    |->> Assigned losses: [-0.21156971  0.0991649  -0.0588404   2.4156997 ]
# >> Total frame loss: 2.2444543838500977
# >> Attempting to reach frame 20 with src: [313, 147,  70,  62] and target: [316, 155,  68,  62]
# Frame path: adnet_datasets/OTB/Rubik/img/0021.jpg
# |->> Beginning tracking for bbox:[313 147  70  62]
# |->> Revisiting bbox: [313 147  70  62]. ACtion 8 did nothing. Breaking action sequence
#    |->> Trajectory ending is FORCED
#    |->> #0/t=5-th Action selection: 8/STOP (P(a|s) = 0.1860000044107437)
#       |->> Bounding box moves to: [313 147  70  62]
#          |->> Action Probabilities (Rounded): [0.0829 0.0702 0.0876 0.0838 0.0816 0.0796 0.0879 0.082  0.1861 0.0756
#  0.0829], argmax=8
#          |->> Action Probabilities (RAW): [0.0828561  0.07015352 0.08755852 0.08382168 0.08157349 0.07961068
#  0.08786697 0.08196567 0.18613198 0.0756043  0.08285706], argmax=8
#          |->> Hit a STOP on the 5-th action!
#     |->> Completed tracking
# >> Calculating frame loss : [313, 147,  70,  62] -> [313, 147,  70,  62] (Target was [316, 155,  68,  62])
#    |->> t=1 Stop-Reward (1.0) for STOP:bbox transition: [313, 147,  70,  62] -> [313, 147,  70,  62] w/ P(a|s)=0.18613198399543762 and iou=0.732685297691373 and reward=1.0 and discount=1.0
#    |->> Assigned losses: [1.6812992]
# >> Total frame loss: 1.6812992095947266
# >> Attempting to reach frame 21 with src: [313, 147,  70,  62] and target: [312, 156,  70,  62]
# Frame path: adnet_datasets/OTB/Rubik/img/0022.jpg
# |->> Beginning tracking for bbox:[313 147  70  62]
#    |->> #0/t=5-th Action selection: 2/RIGHT (P(a|s) = 0.08799999952316284)
#       |->> Bounding box moves to: [315 147  70  62]
#          |->> Action Probabilities (Rounded): [0.0814 0.0726 0.0877 0.0828 0.0791 0.0721 0.0882 0.0808 0.1994 0.0724
#  0.0836], argmax=8
#          |->> Action Probabilities (RAW): [0.08135963 0.07256488 0.08766505 0.0828049  0.07913283 0.07211819
#  0.08819719 0.0807947  0.19940959 0.07238916 0.08356393], argmax=8
#    |->> #1/t=6-th Action selection: 3/2X RIGHT (P(a|s) = 0.07800000160932541)
#       |->> Bounding box moves to: [319 147  70  62]
#          |->> Action Probabilities (Rounded): [0.086  0.0649 0.0705 0.0776 0.0789 0.0713 0.0879 0.0775 0.2415 0.0652
#  0.0786], argmax=8
#          |->> Action Probabilities (RAW): [0.08602282 0.06489332 0.07050454 0.07764536 0.07893404 0.07131787
#  0.08791222 0.07750241 0.24148168 0.0651634  0.07862224], argmax=8
#    |->> #2/t=7-th Action selection: 10/SCALE UP (P(a|s) = 0.07400000095367432)
#       |->> Bounding box moves to: [317 146  72  64]
#          |->> Action Probabilities (Rounded): [0.0721 0.0708 0.0772 0.068  0.075  0.0687 0.079  0.0748 0.2756 0.0644
#  0.0744], argmax=8
#          |->> Action Probabilities (RAW): [0.07205011 0.0707639  0.07718179 0.06799284 0.07499867 0.06871575
#  0.07900082 0.07480698 0.27564564 0.06444185 0.07440162], argmax=8
#    |->> #3/t=8-th Action selection: 5/2X UP (P(a|s) = 0.06199999898672104)
#       |->> Bounding box moves to: [317 144  72  64]
#          |->> Action Probabilities (Rounded): [0.0699 0.0632 0.0712 0.0674 0.0714 0.062  0.0776 0.0751 0.3161 0.0607
#  0.0653], argmax=8
#          |->> Action Probabilities (RAW): [0.06988748 0.06320231 0.07124399 0.06743851 0.07140397 0.06199244
#  0.07762779 0.07506409 0.31606683 0.06074133 0.06533127], argmax=8
# |->> Revisiting bbox: [317 144  72  64]. ACtion 8 did nothing. Breaking action sequence
#    |->> Trajectory ending is FORCED
#     |->> Completed tracking
# >> Calculating frame loss : [313, 147,  70,  62] -> [317, 144,  72,  64] (Target was [312, 156,  70,  62])
#    |->> t=1 Diff-Reward (-0.036) for RIGHT:bbox transition: [313, 147,  70,  62] -> [315, 147,  70,  62] w/ P(a|s)=0.08766505122184753 and iou=0.692337687658413 and reward=-0.035713277900018214 and discount=1.0
#    |->> t=2 Diff-Reward (-0.067) for 2X RIGHT:bbox transition: [315, 147,  70,  62] -> [319, 147,  70,  62] w/ P(a|s)=0.07764536142349243 and iou=0.6251638269986893 and reward=-0.06717386065972364 and discount=1.0
#    |->> t=3 Diff-Reward (0.02) for SCALE UP:bbox transition: [319, 147,  70,  62] -> [317, 146,  72,  64] w/ P(a|s)=0.0744016245007515 and iou=0.6454578889297535 and reward=0.0202940619310642 and discount=1.0
#    |->> t=4 Diff-Reward (-1.0) for 2X UP:bbox transition: [317, 146,  72,  64] -> [317, 144,  72,  64] w/ P(a|s)=0.06199244409799576 and iou=0.6070402298850575 and reward=-1.0 and discount=1.0
#    |->> Assigned losses: [-0.0869344  -0.17166975  0.05272961 -2.780743  ]
# >> Total frame loss: -2.9866175651550293
# >> Attempting to reach frame 22 with src: [317, 144,  72,  64] and target: [316, 152,  67,  68]
# Frame path: adnet_datasets/OTB/Rubik/img/0023.jpg
# |->> Beginning tracking for bbox:[317 144  72  64]
# |->> Revisiting bbox: [317 144  72  64]. ACtion 8 did nothing. Breaking action sequence
#    |->> Trajectory ending is FORCED
#    |->> #0/t=9-th Action selection: 8/STOP (P(a|s) = 0.34200000762939453)
#       |->> Bounding box moves to: [317 144  72  64]
#          |->> Action Probabilities (Rounded): [0.0668 0.0592 0.0707 0.0619 0.0667 0.0558 0.0783 0.0787 0.342  0.0556
#  0.0643], argmax=8
#          |->> Action Probabilities (RAW): [0.06679209 0.05924238 0.07067952 0.06188753 0.06672931 0.05583268
#  0.07825268 0.07868782 0.34203887 0.05558459 0.06427254], argmax=8
#          |->> Hit a STOP on the 9-th action!
#     |->> Completed tracking
# >> Calculating frame loss : [317, 144,  72,  64] -> [317, 144,  72,  64] (Target was [316, 152,  67,  68])
#    |->> t=1 Stop-Reward (-1.0) for STOP:bbox transition: [317, 144,  72,  64] -> [317, 144,  72,  64] w/ P(a|s)=0.3420388698577881 and iou=0.675932699341624 and reward=-1.0 and discount=1.0
#    |->> Assigned losses: [-1.0728309]
# >> Total frame loss: -1.0728309154510498
# >> Attempting to reach frame 23 with src: [317, 144,  72,  64] and target: [310, 155,  72,  62]
# Frame path: adnet_datasets/OTB/Rubik/img/0024.jpg
# |->> Beginning tracking for bbox:[317 144  72  64]
# |->> Revisiting bbox: [317 144  72  64]. ACtion 8 did nothing. Breaking action sequence
#    |->> Trajectory ending is FORCED
#    |->> #0/t=9-th Action selection: 8/STOP (P(a|s) = 0.375)
#       |->> Bounding box moves to: [317 144  72  64]
#          |->> Action Probabilities (Rounded): [0.0649 0.0572 0.0649 0.0626 0.0617 0.0531 0.077  0.0708 0.3747 0.0523
#  0.0606], argmax=8
#          |->> Action Probabilities (RAW): [0.06492712 0.05724061 0.06494242 0.06263341 0.0617112  0.05306502
#  0.0770404  0.07077651 0.37473464 0.05231233 0.06061629], argmax=8
#          |->> Hit a STOP on the 9-th action!
#     |->> Completed tracking
# >> Calculating frame loss : [317, 144,  72,  64] -> [317, 144,  72,  64] (Target was [310, 155,  72,  62])
#    |->> t=1 Stop-Reward (-1.0) for STOP:bbox transition: [317, 144,  72,  64] -> [317, 144,  72,  64] w/ P(a|s)=0.37473464012145996 and iou=0.6122267638173094 and reward=-1.0 and discount=1.0
#    |->> Assigned losses: [-0.9815371]
# >> Total frame loss: -0.9815371036529541
# >> Attempting to reach frame 24 with src: [317, 144,  72,  64] and target: [313, 159,  69,  61]
# Frame path: adnet_datasets/OTB/Rubik/img/0025.jpg
# |->> Beginning tracking for bbox:[317 144  72  64]
#    |->> #0/t=9-th Action selection: 0/LEFT (P(a|s) = 0.06300000101327896)
#       |->> Bounding box moves to: [315 144  72  64]
#          |->> Action Probabilities (Rounded): [0.0631 0.0585 0.0632 0.0614 0.0631 0.0539 0.0719 0.0713 0.3822 0.0498
#  0.0616], argmax=8
#          |->> Action Probabilities (RAW): [0.06309982 0.05846531 0.0631705  0.06142716 0.06314237 0.0538827
#  0.07188395 0.07130766 0.3821614  0.04980935 0.06164982], argmax=8
#    |->> #1/t=10-th Action selection: 0/LEFT (P(a|s) = 0.054999999701976776)
#       |->> Bounding box moves to: [313 144  72  64]
#          |->> Action Probabilities (Rounded): [0.0549 0.0527 0.0713 0.0621 0.0602 0.0533 0.0708 0.0684 0.4014 0.0473
#  0.0576], argmax=8
#          |->> Action Probabilities (RAW): [0.05489171 0.05265525 0.07127938 0.06213581 0.06020078 0.05333776
#  0.07078169 0.06840245 0.40139806 0.0472753  0.05764176], argmax=8
# |->> Revisiting bbox: [315 144  72  64]. ACtion 2 did nothing. Breaking action sequence
#    |->> Trajectory ending is FORCED
#     |->> Completed tracking
# >> Calculating frame loss : [317, 144,  72,  64] -> [313, 144,  72,  64] (Target was [313, 159,  69,  61])
#    |->> t=1 Diff-Reward (0.028) for LEFT:bbox transition: [317, 144,  72,  64] -> [315, 144,  72,  64] w/ P(a|s)=0.06309981644153595 and iou=0.5932417780990242 and reward=0.02772331218993329 and discount=1.0
#    |->> t=2 Diff-Reward (-1.0) for LEFT:bbox transition: [315, 144,  72,  64] -> [313, 144,  72,  64] w/ P(a|s)=0.05489170551300049 and iou=0.6219646799116998 and reward=-1.0 and discount=1.0
#    |->> Assigned losses: [ 0.07660055 -2.902393  ]
# >> Total frame loss: -2.8257925510406494
# >> Attempting to reach frame 25 with src: [313, 144,  72,  64] and target: [314, 157,  67,  62]
# Frame path: adnet_datasets/OTB/Rubik/img/0026.jpg
# |->> Beginning tracking for bbox:[313 144  72  64]
# |->> Revisiting bbox: [313 144  72  64]. ACtion 8 did nothing. Breaking action sequence
#    |->> Trajectory ending is FORCED
#    |->> #0/t=11-th Action selection: 8/STOP (P(a|s) = 0.42100000381469727)
#       |->> Bounding box moves to: [313 144  72  64]
#          |->> Action Probabilities (Rounded): [0.0553 0.0512 0.0703 0.0593 0.0567 0.0509 0.0667 0.0661 0.4209 0.0452
#  0.0572], argmax=8
#          |->> Action Probabilities (RAW): [0.05530438 0.0512316  0.07034363 0.05931603 0.05674546 0.05086283
#  0.06674282 0.06612758 0.42090508 0.04518697 0.0572337 ], argmax=8
#          |->> Hit a STOP on the 11-th action!
#     |->> Completed tracking
# >> Calculating frame loss : [313, 144,  72,  64] -> [313, 144,  72,  64] (Target was [314, 157,  67,  62])
#    |->> t=1 Stop-Reward (-1.0) for STOP:bbox transition: [313, 144,  72,  64] -> [313, 144,  72,  64] w/ P(a|s)=0.42090508341789246 and iou=0.639289055191768 and reward=-1.0 and discount=1.0
#    |->> Assigned losses: [-0.8653479]
# >> Total frame loss: -0.8653479218482971
# >> Attempting to reach frame 26 with src: [313, 144,  72,  64] and target: [313, 158,  70,  62]
# Frame path: adnet_datasets/OTB/Rubik/img/0027.jpg
# |->> Beginning tracking for bbox:[313 144  72  64]
#    |->> #0/t=11-th Action selection: 4/UP (P(a|s) = 0.061000000685453415)
#       |->> Bounding box moves to: [313 143  72  64]
#          |->> Action Probabilities (Rounded): [0.062  0.0533 0.0709 0.0666 0.0613 0.0537 0.0709 0.0671 0.387  0.049
#  0.0582], argmax=8
#          |->> Action Probabilities (RAW): [0.06200098 0.05329293 0.07088678 0.0665805  0.06131197 0.05368194
#  0.0708584  0.06711552 0.38700223 0.04903519 0.05823347], argmax=8
# |->> Revisiting bbox: [313 143  72  64]. ACtion 8 did nothing. Breaking action sequence
#    |->> Trajectory ending is FORCED
#     |->> Completed tracking
# >> Calculating frame loss : [313, 144,  72,  64] -> [313, 143,  72,  64] (Target was [313, 158,  70,  62])
#    |->> t=1 Diff-Reward (-1.0) for UP:bbox transition: [313, 144,  72,  64] -> [313, 143,  72,  64] w/ P(a|s)=0.06131196767091751 and iou=0.6216020297209134 and reward=-1.0 and discount=1.0
#    |->> Assigned losses: [-2.7917802]
# >> Total frame loss: -2.7917802333831787
# >> Attempting to reach frame 27 with src: [313, 143,  72,  64] and target: [313, 160,  68,  62]
# Frame path: adnet_datasets/OTB/Rubik/img/0028.jpg
# |->> Beginning tracking for bbox:[313 143  72  64]
# |->> Revisiting bbox: [313 143  72  64]. ACtion 8 did nothing. Breaking action sequence
#    |->> Trajectory ending is FORCED
#    |->> #0/t=12-th Action selection: 8/STOP (P(a|s) = 0.4090000092983246)
#       |->> Bounding box moves to: [313 143  72  64]
#          |->> Action Probabilities (Rounded): [0.061  0.0501 0.0629 0.0647 0.0575 0.0531 0.0733 0.0663 0.4088 0.0446
#  0.0576], argmax=8
#          |->> Action Probabilities (RAW): [0.06097087 0.05011409 0.06285661 0.0647105  0.05753463 0.05311283
#  0.07329366 0.06632593 0.40884084 0.04460474 0.05763534], argmax=8
#          |->> Hit a STOP on the 12-th action!
#     |->> Completed tracking
# >> Calculating frame loss : [313, 143,  72,  64] -> [313, 143,  72,  64] (Target was [313, 160,  68,  62])
#    |->> t=1 Stop-Reward (-1.0) for STOP:bbox transition: [313, 143,  72,  64] -> [313, 143,  72,  64] w/ P(a|s)=0.4088408350944519 and iou=0.5678749111584932 and reward=-1.0 and discount=1.0
#    |->> Assigned losses: [-0.8944293]
# >> Total frame loss: -0.8944293260574341
# >> Attempting to reach frame 28 with src: [313, 143,  72,  64] and target: [311, 161,  71,  65]
# Frame path: adnet_datasets/OTB/Rubik/img/0029.jpg
# |->> Beginning tracking for bbox:[313 143  72  64]
#    |->> #0/t=12-th Action selection: 7/2X DOWN (P(a|s) = 0.07199999690055847)
#       |->> Bounding box moves to: [313 145  72  64]
#          |->> Action Probabilities (Rounded): [0.0636 0.0516 0.0643 0.0651 0.0594 0.0529 0.0732 0.0718 0.3916 0.0472
#  0.0593], argmax=8
#          |->> Action Probabilities (RAW): [0.06358917 0.0515984  0.0643478  0.06505036 0.05936706 0.05291517
#  0.07320286 0.07181611 0.3916255  0.04722996 0.05925759], argmax=8
# |->> Revisiting bbox: [313 145  72  64]. ACtion 8 did nothing. Breaking action sequence
#    |->> Trajectory ending is FORCED
#     |->> Completed tracking
# >> Calculating frame loss : [313, 143,  72,  64] -> [313, 145,  72,  64] (Target was [311, 161,  71,  65])
#    |->> t=1 Diff-Reward (-1.0) for 2X DOWN:bbox transition: [313, 143,  72,  64] -> [313, 145,  72,  64] w/ P(a|s)=0.0718161091208458 and iou=0.5603112840466926 and reward=-1.0 and discount=1.0
#    |->> Assigned losses: [-2.6336465]
# >> Total frame loss: -2.6336464881896973
# Final bounding box: [313 145  72  64] reached in 13 timesteps (originating from [315 146  70  62]). Target was [311 161  71  65]
#
# ############# END EPISODE # 29 in t=13 timesteps ################
# Avg Loss Across Trajectories:
# Layer Name: conv_1/kernel:0, GRAD NORM = 0.0
# Layer Name: conv_1/bias:0, GRAD NORM = 0.0
# Layer Name: conv_2/kernel:0, GRAD NORM = 0.0
# Layer Name: conv_2/bias:0, GRAD NORM = 0.0
# Layer Name: conv_3/kernel:0, GRAD NORM = 0.0
# Layer Name: conv_3/bias:0, GRAD NORM = 0.0
# Layer Name: fc1/kernel:0, GRAD NORM = 0.0
# Layer Name: fc1/bias:0, GRAD NORM = 0.0
# Layer Name: fc2/kernel:0, GRAD NORM = 0.0
# Layer Name: fc2/bias:0, GRAD NORM = 0.0
# Layer Name: fc3/kernel:0, GRAD NORM = 7.6280317306518555
# Layer Name: fc3/bias:0, GRAD NORM = 1.4977736473083496
# #################################################
# #################################################
#
#
# #############################################
# Dataset=adnet_datasets/OTB/Rubik
# #################################################
#
# ####################### EPISODE # 1 ############################
# Starting bounding box=adnet_datasets/OTB/Rubik/img/0030.jpg for adnet_datasets/OTB/Rubik's frames (index: 0)
# src:adnet_datasets/OTB/Rubik/img/0020.jpg
# target:adnet_datasets/OTB/Rubik/img/0030.jpg.
# >> Attempting to reach frame 20 with src: [317, 150,  70,  62] and target: [316, 155,  68,  62]
# Frame path: adnet_datasets/OTB/Rubik/img/0021.jpg
# |->> Beginning tracking for bbox:[317 150  70  62]
#    |->> #0/t=1-th Action selection: 0/LEFT (P(a|s) = 0.08900000154972076)
#       |->> Bounding box moves to: [315 150  70  62]
#          |->> Action Probabilities (Rounded): [0.0888 0.0844 0.0917 0.0892 0.0892 0.0847 0.0922 0.0898 0.1128 0.0865
#  0.0907], argmax=8
#          |->> Action Probabilities (RAW): [0.08878075 0.08441865 0.0916828  0.08920242 0.08920675 0.08468747
#  0.0921995  0.08978379 0.11284145 0.08647346 0.09072305], argmax=8
#    |->> #1/t=2-th Action selection: 10/SCALE UP (P(a|s) = 0.08799999952316284)
#       |->> Bounding box moves to: [313 149  72  64]
#          |->> Action Probabilities (Rounded): [0.0793 0.0799 0.1028 0.0885 0.0871 0.0832 0.0919 0.0895 0.1288 0.0807
#  0.0883], argmax=8
#          |->> Action Probabilities (RAW): [0.07925573 0.07985509 0.10280982 0.08851478 0.08711317 0.08317605
#  0.09192419 0.08950607 0.12883954 0.08071955 0.088286  ], argmax=8
#    |->> #2/t=3-th Action selection: 0/LEFT (P(a|s) = 0.0860000029206276)
#       |->> Bounding box moves to: [311 149  72  64]
#          |->> Action Probabilities (Rounded): [0.0859 0.0779 0.0896 0.0903 0.0876 0.0787 0.0908 0.0886 0.1446 0.0842
#  0.0818], argmax=8
#          |->> Action Probabilities (RAW): [0.0858863  0.07789571 0.0895929  0.090327   0.08761486 0.07867558
#  0.09080336 0.08855819 0.14463277 0.08417909 0.08183426], argmax=8
# |->> Revisiting bbox: [313 149  72  64]. ACtion 2 did nothing. Breaking action sequence
#    |->> Trajectory ending is FORCED
#     |->> Completed tracking
# >> Calculating frame loss : [317, 150,  70,  62] -> [311, 149,  72,  64] (Target was [316, 155,  68,  62])
#    |->> t=1 Diff-Reward (0.022) for LEFT:bbox transition: [317, 150,  70,  62] -> [315, 150,  70,  62] w/ P(a|s)=0.08878074586391449 and iou=0.8282051282051283 and reward=0.021998668420454393 and discount=1.0
#    |->> t=2 Diff-Reward (-0.02) for SCALE UP:bbox transition: [315, 150,  70,  62] -> [313, 149,  72,  64] w/ P(a|s)=0.08828600496053696 and iou=0.8081967213114755 and reward=-0.020008406893652797 and discount=1.0
#    |->> t=3 Diff-Reward (1.0) for LEFT:bbox transition: [313, 149,  72,  64] -> [311, 149,  72,  64] w/ P(a|s)=0.08588629961013794 and iou=0.7869582827055488 and reward=1.0 and discount=1.0
#    |->> Assigned losses: [ 0.05327166 -0.04856388  2.454731  ]
# >> Total frame loss: 2.4594388008117676
# >> Attempting to reach frame 21 with src: [311, 149,  72,  64] and target: [312, 156,  70,  62]
# Frame path: adnet_datasets/OTB/Rubik/img/0022.jpg
# |->> Beginning tracking for bbox:[311 149  72  64]
#    |->> #0/t=4-th Action selection: 2/RIGHT (P(a|s) = 0.10499999672174454)
#       |->> Bounding box moves to: [313 149  72  64]
#          |->> Action Probabilities (Rounded): [0.0732 0.0721 0.1049 0.0878 0.084  0.0797 0.0912 0.0889 0.1615 0.0752
#  0.0816], argmax=8
#          |->> Action Probabilities (RAW): [0.07321977 0.07209214 0.10488398 0.08775517 0.083967   0.07966028
#  0.09124337 0.08888698 0.16153833 0.0752013  0.08155175], argmax=8
# |->> Revisiting bbox: [313 149  72  64]. ACtion 8 did nothing. Breaking action sequence
#    |->> Trajectory ending is FORCED
#     |->> Completed tracking
# >> Calculating frame loss : [311, 149,  72,  64] -> [313, 149,  72,  64] (Target was [312, 156,  70,  62])
#    |->> t=1 Diff-Reward (1.0) for RIGHT:bbox transition: [311, 149,  72,  64] -> [313, 149,  72,  64] w/ P(a|s)=0.10488398373126984 and iou=0.784247258225324 and reward=1.0 and discount=1.0
#    |->> Assigned losses: [2.2549005]
# >> Total frame loss: 2.2549004554748535
# >> Attempting to reach frame 22 with src: [313, 149,  72,  64] and target: [316, 152,  67,  68]
# Frame path: adnet_datasets/OTB/Rubik/img/0023.jpg
# |->> Beginning tracking for bbox:[313 149  72  64]
#    |->> #0/t=5-th Action selection: 6/DOWN (P(a|s) = 0.09099999815225601)
#       |->> Bounding box moves to: [313 150  72  64]
#          |->> Action Probabilities (Rounded): [0.0984 0.0707 0.0774 0.088  0.0838 0.0747 0.0912 0.083  0.1788 0.0743
#  0.0797], argmax=8
#          |->> Action Probabilities (RAW): [0.09841216 0.07068899 0.07740233 0.08798929 0.08383534 0.07466509
#  0.09115396 0.08304088 0.1788422  0.07426719 0.07970261], argmax=8
#    |->> #1/t=6-th Action selection: 3/2X RIGHT (P(a|s) = 0.08299999684095383)
#       |->> Bounding box moves to: [317 150  72  64]
#          |->> Action Probabilities (Rounded): [0.0746 0.0707 0.0913 0.083  0.087  0.0754 0.0843 0.0835 0.2025 0.0697
#  0.0782], argmax=8
#          |->> Action Probabilities (RAW): [0.07459293 0.07066063 0.09126858 0.08299796 0.08698361 0.07537596
#  0.0842903  0.08350736 0.20249969 0.06965689 0.0781661 ], argmax=8
# |->> Revisiting bbox: [317 150  72  64]. ACtion 8 did nothing. Breaking action sequence
#    |->> Trajectory ending is FORCED
#     |->> Completed tracking
# >> Calculating frame loss : [313, 149,  72,  64] -> [317, 150,  72,  64] (Target was [316, 152,  67,  68])
#    |->> t=1 Diff-Reward (0.024) for DOWN:bbox transition: [313, 149,  72,  64] -> [313, 150,  72,  64] w/ P(a|s)=0.09115396440029144 and iou=0.8291417165668663 and reward=0.024138762066176933 and discount=1.0
#    |->> t=2 Diff-Reward (1.0) for 2X RIGHT:bbox transition: [313, 150,  72,  64] -> [317, 150,  72,  64] w/ P(a|s)=0.08299795538187027 and iou=0.806782334384858 and reward=1.0 and discount=1.0
#    |->> Assigned losses: [0.05781729 2.4889393 ]
# >> Total frame loss: 2.5467565059661865
# >> Attempting to reach frame 23 with src: [317, 150,  72,  64] and target: [310, 155,  72,  62]
# Frame path: adnet_datasets/OTB/Rubik/img/0024.jpg
# |->> Beginning tracking for bbox:[317 150  72  64]
#    |->> #0/t=7-th Action selection: 4/UP (P(a|s) = 0.08100000023841858)
#       |->> Bounding box moves to: [317 149  72  64]
#          |->> Action Probabilities (Rounded): [0.0838 0.0717 0.0782 0.0776 0.0809 0.0733 0.0844 0.0778 0.2264 0.0684
#  0.0776], argmax=8
#          |->> Action Probabilities (RAW): [0.08378014 0.07168315 0.07822003 0.07762443 0.0808812  0.07332134
#  0.08437213 0.07776508 0.22639865 0.06840154 0.07755229], argmax=8
#    |->> #1/t=8-th Action selection: 2/RIGHT (P(a|s) = 0.08100000023841858)
#       |->> Bounding box moves to: [319 149  72  64]
#          |->> Action Probabilities (Rounded): [0.076  0.0672 0.0809 0.0729 0.0741 0.0662 0.0848 0.0772 0.2637 0.0633
#  0.0736], argmax=8
#          |->> Action Probabilities (RAW): [0.07604495 0.06720044 0.08091915 0.07293809 0.07407138 0.06619479
#  0.08484705 0.07717166 0.26371711 0.06330856 0.07358682], argmax=8
#    |->> #2/t=9-th Action selection: 9/SCALE DOWN (P(a|s) = 0.057999998331069946)
#       |->> Bounding box moves to: [320 150  69  62]
#          |->> Action Probabilities (Rounded): [0.0855 0.0613 0.069  0.0691 0.0737 0.0637 0.0784 0.0761 0.2935 0.0578
#  0.0718], argmax=8
#          |->> Action Probabilities (RAW): [0.08553462 0.06133828 0.06902616 0.06908094 0.07372297 0.06368554
#  0.07842313 0.07608703 0.29354116 0.05776798 0.07179213], argmax=8
#    |->> #3/t=10-th Action selection: 7/2X DOWN (P(a|s) = 0.07400000095367432)
#       |->> Bounding box moves to: [320 152  69  62]
#          |->> Action Probabilities (Rounded): [0.0665 0.0625 0.0695 0.0667 0.0684 0.059  0.0778 0.0736 0.3372 0.0509
#  0.0681], argmax=8
#          |->> Action Probabilities (RAW): [0.06651862 0.06245125 0.06946757 0.06669504 0.06835818 0.05903261
#  0.07776612 0.07355133 0.33717638 0.05092015 0.06806272], argmax=8
#    |->> #4/t=11-th Action selection: 2/RIGHT (P(a|s) = 0.06700000166893005)
#       |->> Bounding box moves to: [322 152  69  62]
#          |->> Action Probabilities (Rounded): [0.0651 0.0535 0.0673 0.0598 0.0665 0.0596 0.07   0.0669 0.3804 0.0501
#  0.0608], argmax=8
#          |->> Action Probabilities (RAW): [0.06508978 0.05353728 0.06726167 0.05982436 0.06651509 0.05963569
#  0.06995766 0.06687554 0.38043565 0.0500966  0.06077066], argmax=8
#    |->> #5/t=12-th Action selection: 2/RIGHT (P(a|s) = 0.05900000035762787)
#       |->> Bounding box moves to: [324 152  69  62]
#          |->> Action Probabilities (Rounded): [0.078  0.0576 0.0591 0.0616 0.0657 0.0581 0.0736 0.0664 0.3671 0.0491
#  0.0637], argmax=8
#          |->> Action Probabilities (RAW): [0.0779906  0.0575804  0.05914702 0.0616092  0.0656902  0.05806327
#  0.07362555 0.06641036 0.36711878 0.04909145 0.0636732 ], argmax=8
#    |->> #6/t=13-th Action selection: 10/SCALE UP (P(a|s) = 0.06400000303983688)
#       |->> Bounding box moves to: [322 151  71  64]
#          |->> Action Probabilities (Rounded): [0.0723 0.0585 0.0586 0.0571 0.0665 0.0572 0.0731 0.0661 0.378  0.0487
#  0.064 ], argmax=8
#          |->> Action Probabilities (RAW): [0.07225168 0.05848801 0.05858066 0.05713259 0.06646085 0.05723492
#  0.07308817 0.06605486 0.3779517  0.04873957 0.06401693], argmax=8
#    |->> #7/t=14-th Action selection: 6/DOWN (P(a|s) = 0.07000000029802322)
#       |->> Bounding box moves to: [322 152  71  64]
#          |->> Action Probabilities (Rounded): [0.0658 0.0592 0.0614 0.0583 0.0665 0.057  0.0703 0.0682 0.3797 0.0524
#  0.0612], argmax=8
# ...
#    |->> t=2 Diff-Reward (0.053) for 2X LEFT:bbox transition: [313, 158,  76,  69] -> [309, 158,  76,  69] w/ P(a|s)=0.05957620218396187 and iou=0.5735567970204841 and reward=0.052860936192649643 and discount=1.0
#    |->> t=3 Diff-Reward (-1.0) for 2X DOWN:bbox transition: [309, 158,  76,  69] -> [309, 162,  76,  69] w/ P(a|s)=0.07171953469514847 and iou=0.6407766990291263 and reward=-1.0 and discount=1.0
#    |->> Assigned losses: [-0.07807335  0.14909424 -2.6349921 ]
# >> Total frame loss: -2.5639712810516357
# >> Attempting to reach frame 40 with src: [309, 162,  76,  69] and target: [303, 175,  72,  65]
# Frame path: adnet_datasets/OTB/Rubik/img/0041.jpg
# |->> Beginning tracking for bbox:[309 162  76  69]
#    |->> #0/t=13-th Action selection: 10/SCALE UP (P(a|s) = 0.06300000101327896)
#       |->> Bounding box moves to: [307 160  78  71]
#          |->> Action Probabilities (Rounded): [0.062  0.0558 0.0652 0.0621 0.0612 0.0555 0.0724 0.0671 0.3816 0.0537
#  0.0635], argmax=8
#          |->> Action Probabilities (RAW): [0.0620039  0.05582865 0.06523369 0.06209942 0.061197   0.05550576
#  0.0723836  0.06707928 0.38155097 0.05366378 0.06345396], argmax=8
# |->> Revisiting bbox: [307 160  78  71]. ACtion 8 did nothing. Breaking action sequence
#    |->> Trajectory ending is FORCED
#     |->> Completed tracking
# >> Calculating frame loss : [309, 162,  76,  69] -> [307, 160,  78,  71] (Target was [303, 175,  72,  65])
#    |->> t=1 Diff-Reward (-1.0) for SCALE UP:bbox transition: [309, 162,  76,  69] -> [307, 160,  78,  71] w/ P(a|s)=0.06345396488904953 and iou=0.5940717628705148 and reward=-1.0 and discount=1.0
#    |->> Assigned losses: [-2.7574406]
# >> Total frame loss: -2.7574405670166016
# >> Attempting to reach frame 41 with src: [307, 160,  78,  71] and target: [303, 174,  72,  69]
# Frame path: adnet_datasets/OTB/Rubik/img/0042.jpg
# |->> Beginning tracking for bbox:[307 160  78  71]
#    |->> #0/t=14-th Action selection: 6/DOWN (P(a|s) = 0.07000000029802322)
#       |->> Bounding box moves to: [307 162  78  71]
#          |->> Action Probabilities (Rounded): [0.0619 0.0523 0.0679 0.0614 0.0638 0.0531 0.0705 0.0675 0.3933 0.0518
#  0.0566], argmax=8
#          |->> Action Probabilities (RAW): [0.06189474 0.0523106  0.0679022  0.06137877 0.06375612 0.05306451
#  0.07047582 0.06746798 0.39333668 0.05176506 0.05664748], argmax=8
# |->> Revisiting bbox: [307 162  78  71]. ACtion 8 did nothing. Breaking action sequence
#    |->> Trajectory ending is FORCED
#     |->> Completed tracking
# >> Calculating frame loss : [307, 160,  78,  71] -> [307, 162,  78,  71] (Target was [303, 174,  72,  69])
#    |->> t=1 Diff-Reward (-1.0) for DOWN:bbox transition: [307, 160,  78,  71] -> [307, 162,  78,  71] w/ P(a|s)=0.07047581672668457 and iou=0.6178010471204188 and reward=-1.0 and discount=1.0
#    |->> Assigned losses: [-2.6524856]
# >> Total frame loss: -2.6524856090545654
# >> Attempting to reach frame 42 with src: [307, 162,  78,  71] and target: [301, 176,  73,  65]
# Frame path: adnet_datasets/OTB/Rubik/img/0043.jpg
# |->> Beginning tracking for bbox:[307 162  78  71]
#    |->> #0/t=15-th Action selection: 7/2X DOWN (P(a|s) = 0.06599999964237213)
#       |->> Bounding box moves to: [307 166  78  71]
#          |->> Action Probabilities (Rounded): [0.0607 0.0546 0.0682 0.0642 0.0691 0.0596 0.0712 0.0664 0.3715 0.0529
#  0.0616], argmax=8
#          |->> Action Probabilities (RAW): [0.06071641 0.05463326 0.0681817  0.06422841 0.06907117 0.05962688
#  0.07118738 0.06640437 0.37147245 0.05286629 0.06161162], argmax=8
#    |->> #1/t=16-th Action selection: 10/SCALE UP (P(a|s) = 0.05900000035762787)
#       |->> Bounding box moves to: [305 164  80  73]
#          |->> Action Probabilities (Rounded): [0.063  0.0514 0.0661 0.0624 0.0673 0.0628 0.0675 0.0595 0.3864 0.0545
#  0.0593], argmax=8
#          |->> Action Probabilities (RAW): [0.06296641 0.05137579 0.0660769  0.06242209 0.06726183 0.06278425
#  0.06747241 0.05951537 0.38636565 0.05449599 0.05926332], argmax=8
# |->> Revisiting bbox: [305 164  80  73]. ACtion 8 did nothing. Breaking action sequence
#    |->> Trajectory ending is FORCED
#     |->> Completed tracking
# >> Calculating frame loss : [307, 162,  78,  71] -> [305, 164,  80,  73] (Target was [301, 176,  73,  65])
#    |->> t=1 Diff-Reward (0.069) for 2X DOWN:bbox transition: [307, 162,  78,  71] -> [307, 166,  78,  71] w/ P(a|s)=0.06640436500310898 and iou=0.6596191091026469 and reward=0.06880846553829045 and discount=1.0
#    |->> t=2 Diff-Reward (-1.0) for SCALE UP:bbox transition: [307, 166,  78,  71] -> [305, 164,  80,  73] w/ P(a|s)=0.05926331505179405 and iou=0.6601317440401505 and reward=-1.0 and discount=1.0
#    |->> Assigned losses: [ 0.18660805 -2.825765  ]
# >> Total frame loss: -2.6391568183898926
# >> Attempting to reach frame 43 with src: [305, 164,  80,  73] and target: [302, 175,  72,  69]
# Frame path: adnet_datasets/OTB/Rubik/img/0044.jpg
# |->> Beginning tracking for bbox:[305 164  80  73]
#    |->> #0/t=17-th Action selection: 4/UP (P(a|s) = 0.0689999982714653)
#       |->> Bounding box moves to: [305 162  80  73]
#          |->> Action Probabilities (Rounded): [0.0622 0.054  0.0669 0.0638 0.0687 0.0584 0.0661 0.0604 0.3824 0.056
#  0.0612], argmax=8
#          |->> Action Probabilities (RAW): [0.06220653 0.05399539 0.06687711 0.06376825 0.06865139 0.05838744
#  0.06610877 0.06038141 0.3823949  0.05598792 0.0612409 ], argmax=8
# |->> Revisiting bbox: [305 162  80  73]. ACtion 8 did nothing. Breaking action sequence
#    |->> Trajectory ending is FORCED
#     |->> Completed tracking
# >> Calculating frame loss : [305, 164,  80,  73] -> [305, 162,  80,  73] (Target was [302, 175,  72,  69])
#    |->> t=1 Diff-Reward (-1.0) for UP:bbox transition: [305, 164,  80,  73] -> [305, 162,  80,  73] w/ P(a|s)=0.06865138560533524 and iou=0.620875824835033 and reward=-1.0 and discount=1.0
#    |->> Assigned losses: [-2.678714]
# >> Total frame loss: -2.6787140369415283
# >> Attempting to reach frame 44 with src: [305, 162,  80,  73] and target: [305, 177,  71,  71]
# Frame path: adnet_datasets/OTB/Rubik/img/0045.jpg
# |->> Beginning tracking for bbox:[305 162  80  73]
#    |->> #0/t=18-th Action selection: 9/SCALE DOWN (P(a|s) = 0.054999999701976776)
#       |->> Bounding box moves to: [306 163  77  70]
#          |->> Action Probabilities (Rounded): [0.0606 0.0521 0.0674 0.0641 0.0674 0.0609 0.0748 0.0628 0.3725 0.0549
#  0.0625], argmax=8
#          |->> Action Probabilities (RAW): [0.06061258 0.05214801 0.06736461 0.06414483 0.06738039 0.06088924
#  0.07479549 0.06283811 0.3724852  0.05486703 0.0624745 ], argmax=8
#    |->> #1/t=19-th Action selection: 7/2X DOWN (P(a|s) = 0.06199999898672104)
#       |->> Bounding box moves to: [306 167  77  70]
#          |->> Action Probabilities (Rounded): [0.0619 0.0497 0.0678 0.0668 0.0632 0.0561 0.072  0.0616 0.3915 0.0497
#  0.0598], argmax=8
#          |->> Action Probabilities (RAW): [0.06188623 0.04973451 0.06783224 0.06678688 0.06317142 0.05605127
#  0.07198966 0.06156052 0.39146522 0.04970215 0.05981987], argmax=8
# |->> Revisiting bbox: [306 167  77  70]. ACtion 8 did nothing. Breaking action sequence
#    |->> Trajectory ending is FORCED
#     |->> Completed tracking
# >> Calculating frame loss : [305, 162,  80,  73] -> [306, 167,  77,  70] (Target was [305, 177,  71,  71])
#    |->> t=1 Diff-Reward (-0.007) for SCALE DOWN:bbox transition: [305, 162,  80,  73] -> [306, 163,  77,  70] w/ P(a|s)=0.054867032915353775 and iou=0.6020580555982183 and reward=-0.006843319531162129 and discount=1.0
#    |->> t=2 Diff-Reward (-1.0) for 2X DOWN:bbox transition: [306, 163,  77,  70] -> [306, 167,  77,  70] w/ P(a|s)=0.06156051903963089 and iou=0.6740491092922485 and reward=-1.0 and discount=1.0
#    |->> Assigned losses: [-0.01986508 -2.7877345 ]
# >> Total frame loss: -2.8075995445251465
# Final bounding box: [306 167  77  70] reached in 20 timesteps (originating from [309 169  72  65]). Target was [305 177  71  71]
#
# ############# END EPISODE # 45 in t=20 timesteps ################
# Avg Loss Across Trajectories:
# Layer Name: conv_1/kernel:0, GRAD NORM = 0.0
# Layer Name: conv_1/bias:0, GRAD NORM = 0.0
# Layer Name: conv_2/kernel:0, GRAD NORM = 0.0
# Layer Name: conv_2/bias:0, GRAD NORM = 0.0
# Layer Name: conv_3/kernel:0, GRAD NORM = 0.0
# Layer Name: conv_3/bias:0, GRAD NORM = 0.0
# Layer Name: fc1/kernel:0, GRAD NORM = 0.0
# Layer Name: fc1/bias:0, GRAD NORM = 0.0
# Layer Name: fc2/kernel:0, GRAD NORM = 0.0
# Layer Name: fc2/bias:0, GRAD NORM = 0.0
# Layer Name: fc3/kernel:0, GRAD NORM = 9.232150077819824
# Layer Name: fc3/bias:0, GRAD NORM = 3.6093392372131348
# #################################################
# #################################################
#
#
# #############################################
# Dataset=adnet_datasets/OTB/Rubik
# #################################################
#
# ####################### EPISODE # 1 ############################
# Starting bounding box=adnet_datasets/OTB/Rubik/img/0046.jpg for adnet_datasets/OTB/Rubik's frames (index: 0)
# src:adnet_datasets/OTB/Rubik/img/0036.jpg
# target:adnet_datasets/OTB/Rubik/img/0046.jpg.
# >> Attempting to reach frame 36 with src: [306, 168,  73,  68] and target: [305, 167,  73,  65]
# Frame path: adnet_datasets/OTB/Rubik/img/0037.jpg
# |->> Beginning tracking for bbox:[306 168  73  68]
#    |->> #0/t=1-th Action selection: 7/2X DOWN (P(a|s) = 0.09000000357627869)
#       |->> Bounding box moves to: [306 172  73  68]
#          |->> Action Probabilities (Rounded): [0.0888 0.0844 0.0917 0.0892 0.0892 0.0847 0.0922 0.0898 0.1129 0.0865
#  0.0907], argmax=8
#          |->> Action Probabilities (RAW): [0.08878271 0.08440462 0.09167543 0.0891939  0.08919239 0.08467546
#  0.09222393 0.08979474 0.11288124 0.08650224 0.09067336], argmax=8
#    |->> #1/t=2-th Action selection: 1/2X LEFT (P(a|s) = 0.08100000023841858)
#       |->> Bounding box moves to: [302 172  73  68]
#          |->> Action Probabilities (Rounded): [0.0868 0.0808 0.0925 0.0876 0.089  0.0881 0.089  0.0842 0.1269 0.086
#  0.0891], argmax=8
#          |->> Action Probabilities (RAW): [0.08684897 0.08079968 0.09251937 0.08756462 0.08897635 0.08808419
#  0.08898607 0.08417889 0.12685736 0.08604174 0.08914278], argmax=8
#    |->> #2/t=3-th Action selection: 6/DOWN (P(a|s) = 0.08799999952316284)
#       |->> Bounding box moves to: [302 174  73  68]
#          |->> Action Probabilities (Rounded): [0.0839 0.0734 0.0928 0.0953 0.0883 0.0816 0.0879 0.081  0.1462 0.0819
#  0.0876], argmax=8
#          |->> Action Probabilities (RAW): [0.08394571 0.07336403 0.09282222 0.09526058 0.08832893 0.08158042
#  0.08788697 0.08100712 0.14624135 0.08192327 0.08763939], argmax=8
#    |->> #3/t=4-th Action selection: 10/SCALE UP (P(a|s) = 0.08699999749660492)
#       |->> Bounding box moves to: [300 172  75  70]
#          |->> Action Probabilities (Rounded): [0.0787 0.0724 0.0909 0.0902 0.0909 0.0815 0.0857 0.0807 0.164  0.0783
#  0.0869], argmax=8
#          |->> Action Probabilities (RAW): [0.07869898 0.07237784 0.09087115 0.09016488 0.09087706 0.08149198
#  0.08567581 0.08072495 0.16395314 0.07828807 0.08687612], argmax=8
# |->> Revisiting bbox: [300 172  75  70]. ACtion 8 did nothing. Breaking action sequence
#    |->> Trajectory ending is FORCED
#     |->> Completed tracking
# >> Calculating frame loss : [306, 168,  73,  68] -> [300, 172,  75,  70] (Target was [305, 167,  73,  65])
#    |->> t=1 Diff-Reward (-0.102) for 2X DOWN:bbox transition: [306, 168,  73,  68] -> [306, 172,  73,  68] w/ P(a|s)=0.08979474008083344 and iou=0.8016329560215253 and reward=-0.10171932784438331 and discount=1.0
#    |->> t=2 Diff-Reward (-0.039) for 2X LEFT:bbox transition: [306, 172,  73,  68] -> [302, 172,  73,  68] w/ P(a|s)=0.08079968392848969 and iou=0.7623888182973316 and reward=-0.03924413772419366 and discount=1.0
#    |->> t=3 Diff-Reward (-0.044) for DOWN:bbox transition: [302, 172,  73,  68] -> [302, 174,  73,  68] w/ P(a|s)=0.08788697421550751 and iou=0.7187112763320942 and reward=-0.04367754196523743 and discount=1.0
#    |->> t=4 Diff-Reward (1.0) for SCALE UP:bbox transition: [302, 174,  73,  68] -> [300, 172,  75,  70] w/ P(a|s)=0.08687612414360046 and iou=0.724762726488352 and reward=1.0 and discount=1.0
#    |->> Assigned losses: [-0.24516687 -0.09872971 -0.10621084  2.443272  ]
# >> Total frame loss: 1.9931645393371582
# >> Attempting to reach frame 37 with src: [300, 172,  75,  70] and target: [303, 170,  72,  64]
# Frame path: adnet_datasets/OTB/Rubik/img/0038.jpg
# |->> Beginning tracking for bbox:[300 172  75  70]
#    |->> #0/t=5-th Action selection: 5/2X UP (P(a|s) = 0.07800000160932541)
#       |->> Bounding box moves to: [300 168  75  70]
#          |->> Action Probabilities (Rounded): [0.0772 0.0678 0.0902 0.0882 0.0855 0.0785 0.0854 0.0806 0.1887 0.0792
#  0.0787], argmax=8
#          |->> Action Probabilities (RAW): [0.07723099 0.06777456 0.09018619 0.0881957  0.08552266 0.07848768
#  0.08542307 0.08061285 0.1886864  0.07915663 0.07872333], argmax=8
#    |->> #1/t=6-th Action selection: 3/2X RIGHT (P(a|s) = 0.08100000023841858)
#       |->> Bounding box moves to: [304 168  75  70]
#          |->> Action Probabilities (Rounded): [0.0744 0.0679 0.0884 0.0806 0.0812 0.0706 0.0876 0.0854 0.2115 0.0726
#  0.08  ], argmax=8
#          |->> Action Probabilities (RAW): [0.07436474 0.06785718 0.08835148 0.08056769 0.08115795 0.07057114
#  0.0876319  0.08540548 0.21145098 0.07264702 0.07999443], argmax=8
# |->> Revisiting bbox: [304 168  75  70]. ACtion 8 did nothing. Breaking action sequence
#    |->> Trajectory ending is FORCED
#     |->> Completed tracking
# >> Calculating frame loss : [300, 172,  75,  70] -> [304, 168,  75,  70] (Target was [303, 170,  72,  64])
#    |->> t=1 Diff-Reward (0.05) for 2X UP:bbox transition: [300, 172,  75,  70] -> [300, 168,  75,  70] w/ P(a|s)=0.07848767936229706 and iou=0.8777142857142857 and reward=0.050128078817733956 and discount=1.0
#    |->> t=2 Diff-Reward (1.0) for 2X RIGHT:bbox transition: [300, 168,  75,  70] -> [304, 168,  75,  70] w/ P(a|s)=0.08056768774986267 and iou=0.8550997365449755 and reward=1.0 and discount=1.0
#    |->> Assigned losses: [0.12756662 2.5186577 ]
# >> Total frame loss: 2.6462242603302
# >> Attempting to reach frame 38 with src: [304, 168,  75,  70] and target: [306, 168,  71,  68]
# Frame path: adnet_datasets/OTB/Rubik/img/0039.jpg
# |->> Beginning tracking for bbox:[304 168  75  70]
#    |->> #0/t=7-th Action selection: 9/SCALE DOWN (P(a|s) = 0.07199999690055847)
#       |->> Bounding box moves to: [305 169  72  67]
#          |->> Action Probabilities (Rounded): [0.0786 0.0712 0.0798 0.0759 0.0785 0.0687 0.0838 0.0775 0.238  0.0721
#  0.0758], argmax=8
#          |->> Action Probabilities (RAW): [0.07863646 0.07120897 0.0797905  0.07593063 0.07852819 0.06873658
#  0.08383696 0.07746785 0.23797505 0.07212532 0.07576343], argmax=8
#    |->> #1/t=8-th Action selection: 10/SCALE UP (P(a|s) = 0.07599999755620956)
#       |->> Bounding box moves to: [303 167  74  69]
#          |->> Action Probabilities (Rounded): [0.0721 0.0642 0.0786 0.0761 0.0753 0.0645 0.0822 0.078  0.2714 0.0619
#  0.0755], argmax=8
#          |->> Action Probabilities (RAW): [0.07211536 0.06424563 0.07855842 0.07611086 0.07534406 0.06451897
#  0.082233   0.07804661 0.27137363 0.06193236 0.07552106], argmax=8
#    |->> #2/t=9-th Action selection: 9/SCALE DOWN (P(a|s) = 0.06199999898672104)
#       |->> Bounding box moves to: [304 168  71  66]
#          |->> Action Probabilities (Rounded): [0.0671 0.06   0.0757 0.0723 0.0755 0.0631 0.077  0.0763 0.3035 0.0618
#  0.0678], argmax=8
#          |->> Action Probabilities (RAW): [0.06705941 0.05998817 0.07569309 0.0722838  0.07551154 0.0630866
#  0.07697217 0.07627919 0.30352765 0.06175589 0.06784249], argmax=8
#    |->> #3/t=10-th Action selection: 1/2X LEFT (P(a|s) = 0.0560000017285347)
#       |->> Bounding box moves to: [300 168  71  66]
#          |->> Action Probabilities (Rounded): [0.0624 0.0563 0.0708 0.0697 0.0674 0.0551 0.0756 0.0721 0.352  0.0518
#  0.0667], argmax=8
#          |->> Action Probabilities (RAW): [0.06240484 0.05625173 0.07080317 0.06967162 0.06744479 0.05514812
#  0.07559036 0.07214658 0.35203832 0.0517705  0.06672999], argmax=8

# %%
# Plot losses
fig = plt.figure()
all_losses = np.concatenate([v for _, v in losses.items()])
plt.plot(np.arange(len(all_losses)), all_losses) 
plt.xlabel('Number of Episodes')
plt.ylabel('Avg Trajectory Loss')

# %% [markdown]
# ### Save Weights for Reproducibility

# %%
# !mkdir -p derek_models

dt_string = datetime.now().strftime("%d-%m-%Y_%H%M%S")
model.save('derek_models/{0}'.format(dt_string))





dt_string = datetime.now().strftime("%d-%m-%Y_%H%M%S")
model.save_weights("checkpoints/derek-{0}.h5".format(dt_string))
# Out:
# INFO:tensorflow:Assets written to: derek_models/19-12-2021_225315/assets
# INFO:tensorflow:Assets written to: derek_models/19-12-2021_225315/assets

# %%
# %debug

# %%
# UNTESTED; uncomfirmed if works

def move2Frame(model: ADNET, img: np.array, src_frame: int, src_bbox: np.array, 
               target_frame: int, target_bbox: np.array) -> np.array:
  
  bbox = src_bbox
  actions = []
  img = getFrame(dataset, target_frame) 
  target_bbox = gt[i]
  for t in range(model.K):
    patch = getPatch(img, bbox)
    probs, conf_score = model(patch)
    a_prob = tf.reshape(probs, (model.ACTION_DIM)) 
    a, bbox = selectMaxAction(np.array(img), bbox, a_prob)

    actions.append(a)
    model.updateActionHistory(a)
    if isStop(a):
        break  
  
  target_iou = calculate_IOU(bbox, target_bbox)   
  return bbox, target_iou, actions


def predict(model: ADNET, d: str, start_frame: int, end_frame: int):
  gt = get_ground_truths("%s/groundtruth_rect.txt" % d)
  frames = sorted(glob.glob(os.path.join('%s/img' % d, '*.jpg'))) 

  ious = []
  bbox = gt[start_frame]
  model.clearActionHistory()
  for i in range(start_frame+1, end_frame+1):
    img = getFrame(dataset, i) 
    bbox, iou, actions = move2Frame(model, img, d)
    ious.append(iou)
  return model, ious


def predict(model: ADNET, d: str):
  gt = get_ground_truths("%s/groundtruth_rect.txt" % d)
  frames = sorted(glob.glob(os.path.join('%s/img' % d, '*.jpg'))) 
  return predict(model, d, 0, len(frames)-1)



rand_idx = 11
d = ALL_DATASETS_LIST[rand_idx] 
model, ious = predict(adnet_model, d)

fig = plt.figure()
for e in losses:
  plt.plot(np.arange(len(ious)), ious) 
plt.xlabel('Frame')
plt.ylabel('IOU')

# %% [markdown]
# ### Observations
#
# * The paper sums all sequence rewards. However, we found this to produce too much variance. We reduce_mean instead to address this. If we had

# %% [markdown]
# # Prediction

# %%
print(erroneous_datasets)

# !ls adnet_datasets/OTB/Diving/img/
# ! wc -l adnet_datasets/OTB/Diving/groundtruth_rect.txt

# %%
def predict(model: tf.keras.Model,img: np.array,bbox: np.array) -> np.array:
  ACTION_DIM=11
  K=10
  
  action_hist = np.zeros((ACTION_DIM * K, 1))
  seen_bboxes = set()
  for t in range(K):
    #model.setActionHistory(action_hist.reshape((1, 1, 1, ACTION_DIM * K)))
    model.setActionHistory(action_hist.reshape((1,ACTION_DIM * K))) ### For ADNET_v2
    patch = tf.image.resize(img[bbox[1]:(bbox[1] + bbox[3]), 
                                bbox[0]:(bbox[0] + bbox[2])], [112, 112])
    patch = tf.reshape(patch, (1, 112, 112, 3))
    a_prob = tf.reshape(model(patch)[0], (ACTION_DIM)) 
    a, bbox = selectAction(np.array(img), bbox, a_prob)
    if isStop(a) or tuple(bbox) in seen_bboxes:
      break

    action_hist[t * ACTION_DIM + a] = 1 
    seen_bboxes.add(tuple(bbox))
  return bbox

# %%
def plotNpImageBBoxGT(img: np.array, bbox: np.array,gbbox: np.array) -> np.array:
  '''
  Plots the bounding box on an image and returns the bounding box
  '''
  fig, ax = plt.subplots()
  x_pre,y_pre, w_pre, h_pre = bbox
  x_gr,y_gr, w_gr, h_gr = gbbox
  predicted_rect = patches.Rectangle((x_pre, y_pre), w_pre, h_pre, linewidth=1, edgecolor='r', facecolor='none')
  gt_rect = patches.Rectangle((x_gr, y_gr), w_gr, h_gr, linewidth=1, edgecolor='b', facecolor='none')
  ax.add_patch(predicted_rect)
  ax.add_patch(gt_rect)
  plt.imshow(img)
  return bbox

# %%
ALL_DATASETS_LIST = glob.glob("adnet_datasets/OTB/*")
j = random.randint(0, len(ALL_DATASETS_LIST)) 
dataset = ALL_DATASETS_LIST[j] 
frames = sorted(glob.glob(os.path.join('%s/img' % dataset, '*.jpg')))
gt = get_ground_truths("%s/groundtruth_rect.txt" % dataset)

predicted_bbox = gt[0]
for i, frame in enumerate(frames[1:]):
  img = cv2.imread(frame)
  img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
  print(img.shape)
  predicted_bbox=predict(model,img,predicted_bbox)
  print(predicted_bbox)
  gtbbox=gt[i]
  plotNpImageBBoxGT(img,predicted_bbox,gtbbox)
  #print(gtbbox)
  #print(predicted_bbox)
  break
  #bbox = 
  #print(model)

# %%
def test_metrics( model: tf.keras.Model, model2:tf.keras.Model  ):
    all_boxes = []
    all_gt = []
    time_perframe_for_each_video =[]
    test_list = glob.glob("adnet_datasets/Test/*")
    d = ALL_DATASETS_LIST[rand_idx] 
    gt = get_ground_truths("%s/groundtruth_rect.txt" % d)
  
    for  i in range(len(test_list)):  # start with 1
      dataset = test_list[i]
      print(dataset)
      #frames = sorted(glob.glob(os.path.join('%s/img' % dataset, '*.jpg')))
      gt = get_ground_truths("%s/groundtruth_rect.txt" % dataset)     
      all_gt.append(gt)
      frames = sorted(glob.glob(os.path.join('%s/img' % dataset, '*.jpg')))
      print(frames)
      number_of_frames = len(frames)
      #start_frame = random.randint(0, number_of_frames) maybe to test robustnes do not start always with first frame TRE
      start_frame = 0
      boxes_m1 =[]
      boxes_m2 = []
      time_perframe = []
      predicted_box = gt[0]
      predicted_box2 = gt[0]
      start = time.time()
      for f in range(len(frames) - start_frame):
        img = cv2.imread(frames[f])
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
        predicted_bbox=predict(model,img,predicted_box)
        #predicted_bbox2 = predict(model, img,predicted_bbox) if we want to compare 2 models
        boxes_m1.append(predicted_box)
        #boxes_m2.append(predicted_bbox)
      end = time.time()
      time_perframe = (start-end)/len(frames)
      all_boxes.append(boxes_m1)
      time_perframe_for_each_video.append(time_perframe)
    return all_boxes, all_gt , time_perframe_for_each_video



all_boxes, all_gt , time_perframe_for_each_video = test_metrics(model , adnet_model)
print (all_boxes)
print(all_gt)

# %% [markdown]
# # TESTING & DEBUGGING

# %%
# Update this with the appropriate dataset
TEST_IMAGE_PATH = "adnet_datasets/OTB/Couple/img/0082.jpg"
TEST_BBOX = get_ground_truths("adnet_datasets/OTB/Couple/groundtruth_rect.txt")[82]
TEST_IMAGE = cv2.imread(TEST_IMAGE_PATH)


# Update the following two vars
src_bbox = np.array([143, 131, 34, 87]) 
pred_bbox = np.array([138, 41, 32, 89])
print(plotNpImageBBoxes(TEST_IMAGE, src_bbox, TEST_BBOX, pred_bbox))


print("IOU: {0}".format(calculate_IOU(pred_bbox, src_bbox)))

print("Test bbox is: {0}".format(TEST_BBOX))

# %%
# VERTICAL MOVEMENT TESTING 
TEST_IMAGE_PATH = "adnet_datasets/OTB/Skater2/img/0005.jpg"
TEST_BBOX = get_ground_truths("adnet_datasets/OTB/Skater2/groundtruth_rect.txt")[4]
TEST_IMAGE = cv2.imread(TEST_IMAGE_PATH)

# Test move down
print("Down-shifted bounding box")
bbox = move2(img, TEST_BBOX, "down")
print(plotNpImageBBox(img, bbox))

print("Down-shifted bounding box")
bbox = move2(img, bbox, "down")
print(plotNpImageBBox(img, bbox))

print("Down-shifted bounding box")
bbox = move2(img, bbox, "down")
print(plotNpImageBBox(img, bbox))

print("Down-shifted bounding box")
bbox = move2(img, bbox, "down")
print(plotNpImageBBox(img, bbox))


print("Down-shifted bounding box")
bbox = move2(img, bbox, "down")
print(plotNpImageBBox(img, bbox))

# %%
# HORIZONTAL MOVEMENT TESTING 
TEST_IMAGE_PATH = "adnet_datasets/OTB/Skater2/img/0005.jpg"
TEST_BBOX = get_ground_truths("adnet_datasets/OTB/Skater2/groundtruth_rect.txt")[4]
TEST_IMAGE = cv2.imread(TEST_IMAGE_PATH)

img, bbox = TEST_IMAGE, TEST_BBOX
print("Original bounding box")
print(plotNpImageBBox(img, TEST_BBOX))

# Test move left
print("Left-shifted bounding box")
bbox = move2(img, TEST_BBOX, "left")
print(plotNpImageBBox(img, bbox))

# %%
# MOVEMENT TEST

print("IOU between {1} and {2} is {0}".format(calculate_IOU(np.array([143, 131,  34,  87]), np.array([138,  41,  32,  89])), [143, 131,  34,  87], [138,  41,  32,  89]))

for i in range(11):
  print(selectAction(np.zeros([300, 300, 3]), np.array([252, 65, 25, 30]), i))

print(selectAction(np.zeros([300, 300, 3]), np.array([131,7,117,168]), 5))
print("The following UP should do nothing because 0.03 * 168 * 2 is too large")
print(selectAction(np.zeros([300, 300, 3]), np.array([131,7,117,168]), 5))

# %%
print(selectAction(np.zeros([450, 450, 3]), np.array([315,  0, 32,  35]), 5))
